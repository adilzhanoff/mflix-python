# %%
# import the pymongo library - this is the Python driver!
import pymongo

# replace "uri" with your Atlas URI string - should look like mongodb+srv://...
uri = "mongodb://localhost:27017/"
client = pymongo.MongoClient(uri)
db = client['sample_mflix']

# movies is our collection handle - it refers to the sample_mflix.movies collection
# movies = mflix.movies

# %%
# find one document in the "movies" collection - does not matter which one
db.movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'),
#  'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#  'genres': ['Short'],
#  'runtime': 1,
#  'cast': ['Charles Kayser', 'John Ott'],
#  'num_mflix_comments': 1,
#  'title': 'Blacksmith Scene',
#  'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#  'countries': ['USA'],
#  'released': datetime.datetime(1893, 5, 9, 0, 0),
#  'directors': ['William K.L. Dickson'],
#  'rated': 'UNRATED',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-26 00:03:50.133000000',
#  'year': 1893,
#  'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5},
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184, 'meter': 32},
#   'lastUpdated': datetime.datetime(2015, 6, 28, 18, 34, 9)}}

# %%
# find one document in the "movies" collection - must have "Salma Hayek" in the "cast"
db.movies.find_one({"cast": "Salma Hayek"})
# Out:
# {'_id': ObjectId('573a1399f29313caabceea6d'),
#  'plot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'genres': ['Action', 'Drama'],
#  'runtime': 95,
#  'rated': 'R',
#  'cast': ['David Arquette', 'John Hawkes', 'Salma Hayek', 'Jason Wiles'],
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'Roadracers',
#  'fullplot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'languages': ['English'],
#  'released': datetime.datetime(1994, 7, 22, 0, 0),
#  'directors': ['Robert Rodriguez'],
#  'writers': ['Robert Rodriguez', 'Tommy Nix'],
#  'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#  'lastupdated': '2015-09-01 00:53:54.567000000',
#  'year': 1994,
#  'imdb': {'rating': 6.7, 'votes': 2036, 'id': 111002},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 7487, 'meter': 31},
#   'dvd': datetime.datetime(2002, 9, 3, 0, 0),
#   'critic': {'rating': 4.9, 'numReviews': 23, 'meter': 26},
#   'lastUpdated': datetime.datetime(2015, 9, 11, 18, 0, 30),
#   'rotten': 17,
#   'production': 'Hollywood Pictures',
#   'fresh': 6}}

# %%
# find all the documents in the "movies" collection with "Salma Hayek" in the "cast"
# this returns a cursor, which IS a Python iterable, but is NOT a document!
db.movies.find({"cast": "Salma Hayek"})

# %%
# return the count of movies with "Salma Hayek" in the "cast"
# db.movies.find({"cast": "Salma Hayek"}).count()
db.movies.count_documents({"cast": "Salma Hayek"})
# Out:
# 21

# %%
# find all movies with Salma Hayek
# then pretty print
cursor = db.movies.find({"cast": "Salma Hayek"})
from bson.json_util import dumps
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabceea6d"
#     },
#     "plot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "genres": [
#       "Action",
#       "Drama"
#     ],
#     "runtime": 95,
#     "rated": "R",
#     "cast": [
#       "David Arquette",
#       "John Hawkes",
#       "Salma Hayek",
#       "Jason Wiles"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Roadracers",
#     "fullplot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 774835200000
#     },
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "writers": [
#       "Robert Rodriguez",
#       "Tommy Nix"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-09-01 00:53:54.567000000",
#     "year": 1994,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 2036,
#       "id": 111002
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 7487,
#         "meter": 31
#       },
#       "dvd": {
#         "$date": 1031011200000
#       },
#       "critic": {
#         "rating": 4.9,
#         "numReviews": 23,
#         "meter": 26
#       },
#       "lastUpdated": {
#         "$date": 1441994430000
#       },
#       "rotten": 17,
#       "production": "Hollywood Pictures",
#       "fresh": 6
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef0b6"
#     },
#     "plot": "Based on the Nobel Prize Winner's novel, the Egyptian Naguib Mahfouz. The story, translated from El Cairo to Mexico City's downtown, narrates the life of the members of the neighbourhood ...",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 140,
#     "rated": "UNRATED",
#     "cast": [
#       "Ernesto G\u00e8mez Cruz",
#       "Mar\u00e8a Rojo",
#       "Salma Hayek",
#       "Bruno Bichir"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BNzM2NTRlNDMtMTBmMi00NTk0LTllMmQtNzQxMjQxOGFmOGQ3XkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Midaq Alley",
#     "fullplot": "Based on the Nobel Prize Winner's novel, the Egyptian Naguib Mahfouz. The story, translated from El Cairo to Mexico City's downtown, narrates the life of the members of the neighbourhood and the connection between them Don Ru, the owner of the local pub; Eusebia, his wife; Chava, his son and Abel his friend, who emigrate to USA in search of fortune; Susanita, the single landtender always dreaming to marry a good man; Guicho, the pub's employee, who extracts the money when Don Ru is not there and finally marries Susanita; Alma, the very good looking girl, the Abel's dream, who becomes a luxury prostitute while he's away; Jimmy, the handsome young man Don Ru becomes infatuated with, etc. This movie won the Ariel (the Mexican Oscar) as best movie in 1995.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": 889142400000
#     },
#     "directors": [
#       "Jorge Fons"
#     ],
#     "writers": [
#       "Vicente Le\u00e8ero (screenplay)",
#       "Naguib Mahfouz (novel)"
#     ],
#     "awards": {
#       "wins": 27,
#       "nominations": 14,
#       "text": "27 wins & 14 nominations."
#     },
#     "lastupdated": "2015-09-01 01:14:01.613000000",
#     "year": 1995,
#     "imdb": {
#       "rating": 7.6,
#       "votes": 2013,
#       "id": 112619
#     },
#     "countries": [
#       "Mexico"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.5,
#         "numReviews": 721,
#         "meter": 79
#       },
#       "dvd": {
#         "$date": 982022400000
#       },
#       "lastUpdated": {
#         "$date": 1435430492000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef179"
#     },
#     "fullplot": "With this sequel to his prize-winning independent previous film, \"El Mariachi,\" director Robert Rodriquez joins the ranks of Sam Peckinpah and John Woo as a master of slick, glamorized ultra-violence. We pick up the story as a continuation of \"El Mariachi,\" where an itinerant musician, looking for work, gets mistaken for a hitman and thereby entangled in a web of love, corruption, and death. This time, he is out to avenge the murder of his lover and the maiming of his fretting hand, which occurred at the end of the earlier movie. However, the plot is recapitulated, and again, a case of mistaken identity leads to a very high body count, involvement with a beautiful woman who works for the local drug lord, and finally, the inevitable face-to-face confrontation and bloody showdown.",
#     "imdb": {
#       "rating": 7.2,
#       "votes": 127966,
#       "id": 112851
#     },
#     "year": 1995,
#     "plot": "A gunslinger is embroiled in a war with a local drug runner.",
#     "genres": [
#       "Action",
#       "Crime",
#       "Thriller"
#     ],
#     "rated": "R",
#     "metacritic": 55,
#     "title": "Desperado",
#     "lastupdated": "2015-08-29 00:25:05.467000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Robert Rodriguez"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.5,
#         "numReviews": 187644,
#         "meter": 80
#       },
#       "dvd": {
#         "$date": 867196800000
#       },
#       "critic": {
#         "rating": 6.4,
#         "numReviews": 39,
#         "meter": 62
#       },
#       "lastUpdated": {
#         "$date": 1442165457000
#       },
#       "rotten": 15,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 24
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYjA0NDMyYTgtMDgxOC00NGE0LWJkOTQtNDRjMjEzZmU0ZTQ3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 1,
#     "released": {
#       "$date": 809308800000
#     },
#     "awards": {
#       "wins": 0,
#       "nominations": 4,
#       "text": "4 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Joaquim de Almeida",
#       "Cheech Marin"
#     ],
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "runtime": 104
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf092d"
#     },
#     "plot": "After a one night stand with Isabel, Alex realizes that she is pregnant and they decide to get married. However, along with the marriage comes compromise of one's own cultural traditions.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 109,
#     "metacritic": 37,
#     "rated": "PG-13",
#     "cast": [
#       "Matthew Perry",
#       "Salma Hayek",
#       "Jon Tenney",
#       "Carlos G\u00e8mez"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BM2Q3MzA3YmYtNzUzNS00NDhhLTkyZmYtMDU2YmE1ODY5MjdmXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Fools Rush In",
#     "fullplot": "Sparks fly and cultures collide in this romantic comedy about a casual night of passion that turns into the love of a lifetime. Alex Whitman is a New Yorker sent to Las Vegas to oversee a construction project. There he meets Isabel Fuentes, and some serious chemistry brings them together for one night. But Alex doesn't see Isabel again until three months later, when he learns she is pregnant. On a whim and prayer, he proposes. However, there's more to marriage than a Vegas chapel and an Elvis impersonator, as Alex and Isabel soon learn.",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": 855878400000
#     },
#     "directors": [
#       "Andy Tennant"
#     ],
#     "writers": [
#       "Joan Taylor (story)",
#       "Katherine Reback (story)",
#       "Katherine Reback (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 2,
#       "text": "2 nominations."
#     },
#     "lastupdated": "2015-09-07 00:52:44.310000000",
#     "year": 1997,
#     "imdb": {
#       "rating": 6.0,
#       "votes": 26104,
#       "id": 119141
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.0,
#         "numReviews": 62870,
#         "meter": 64
#       },
#       "dvd": {
#         "$date": 887068800000
#       },
#       "critic": {
#         "rating": 4.8,
#         "numReviews": 27,
#         "meter": 33
#       },
#       "lastUpdated": {
#         "$date": 1439923914000
#       },
#       "rotten": 18,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 9
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf09f1"
#     },
#     "plot": "Based on the novel, a young gypsy becomes a Minister's obsession in 1483. Only the bell ringer and her husband and the court of miracles can save her.",
#     "genres": [
#       "Drama",
#       "Horror",
#       "Romance"
#     ],
#     "runtime": 98,
#     "cast": [
#       "Mandy Patinkin",
#       "Richard Harris",
#       "Salma Hayek",
#       "Edward Atterton"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTMxNTk1MTEyNV5BMl5BanBnXkFtZTcwMDk3MjYyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Hunchback",
#     "fullplot": "Based on the novel, a young gypsy becomes a Minister's obsession in 1483. Only the bell ringer and her husband and the court of miracles can save her.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 858470400000
#     },
#     "directors": [
#       "Peter Medak"
#     ],
#     "writers": [
#       "Victor Hugo (novel)",
#       "John Fasano (teleplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 12,
#       "text": "Nominated for 4 Primetime Emmys. Another 8 nominations."
#     },
#     "lastupdated": "2015-08-12 00:16:56.157000000",
#     "year": 1997,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 1129,
#       "id": 119329
#     },
#     "countries": [
#       "USA",
#       "Hungary",
#       "Canada",
#       "Czech Republic"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.9,
#         "numReviews": 50,
#         "meter": 39
#       },
#       "dvd": {
#         "$date": 895536000000
#       },
#       "lastUpdated": {
#         "$date": 1438365919000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0e4f"
#     },
#     "plot": "Famous 70s NYC nightclub seen and told through the eyes of a young employee.",
#     "genres": [
#       "Drama",
#       "Music"
#     ],
#     "runtime": 93,
#     "metacritic": 33,
#     "rated": "R",
#     "cast": [
#       "Ryan Phillippe",
#       "Salma Hayek",
#       "Neve Campbell",
#       "Mike Myers"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIzNzIxMjEtZDNiZS00Y2E1LTkwOTItZGJjOTMwYzU4YzVmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg",
#     "title": "54",
#     "lastupdated": "2015-09-16 12:22:02.100000000",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 904262400000
#     },
#     "directors": [
#       "Mark Christopher"
#     ],
#     "writers": [
#       "Mark Christopher"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 7,
#       "text": "7 nominations."
#     },
#     "year": 1998,
#     "imdb": {
#       "rating": 5.8,
#       "votes": 26612,
#       "id": 120577
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/movie/54",
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 31237,
#         "meter": 44
#       },
#       "dvd": {
#         "$date": 986256000000
#       },
#       "critic": {
#         "rating": 4.2,
#         "numReviews": 66,
#         "meter": 15
#       },
#       "lastUpdated": {
#         "$date": 1440270591000
#       },
#       "consensus": "Poor plot development and slow pacing keep 54 from capturing the energy of it's legendary namesake.",
#       "rotten": 56,
#       "production": "Miramax Films",
#       "fresh": 10
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0ea6"
#     },
#     "fullplot": "\"Frida\" chronicles the life Frida Kahlo shared unflinchingly and openly with Diego Rivera, as the young couple took the art world by storm. From her complex and enduring relationship with her mentor and husband to her illicit and controversial affair with Leon Trotsky, to her provocative and romantic entanglements with women, Frida Kahlo lived a bold and uncompromising life as a political, artistic, and sexual revolutionary.",
#     "imdb": {
#       "rating": 7.4,
#       "votes": 57256,
#       "id": 120679
#     },
#     "year": 2002,
#     "plot": "A biography of artist Frida Kahlo, who channeled the pain of a crippling injury and her tempestuous marriage into her work.",
#     "genres": [
#       "Biography",
#       "Drama",
#       "Romance"
#     ],
#     "rated": "R",
#     "metacritic": 61,
#     "title": "Frida",
#     "lastupdated": "2015-09-12 00:33:36.510000000",
#     "languages": [
#       "English",
#       "French",
#       "Russian"
#     ],
#     "writers": [
#       "Hayden Herrera (book)",
#       "Clancy Sigal (screenplay)",
#       "Diane Lake (screenplay)",
#       "Gregory Nava (screenplay)",
#       "Anna Thomas (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/frida/",
#       "viewer": {
#         "rating": 3.7,
#         "numReviews": 53261,
#         "meter": 86
#       },
#       "dvd": {
#         "$date": 1055203200000
#       },
#       "critic": {
#         "rating": 6.9,
#         "numReviews": 151,
#         "meter": 76
#       },
#       "boxOffice": "$25.7M",
#       "consensus": "Frida is a passionate, visually striking biopic about the larger-than-life artist.",
#       "rotten": 36,
#       "production": "Miramax Films",
#       "lastUpdated": {
#         "$date": 1442167714000
#       },
#       "fresh": 115
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYzUxMTU0ZmEtZWE0Ni00NzJlLThhZTUtNDA1ZDZjZDUxYThiXkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 2,
#     "released": {
#       "$date": 1037923200000
#     },
#     "awards": {
#       "wins": 19,
#       "nominations": 33,
#       "text": "Won 2 Oscars. Another 17 wins & 33 nominations."
#     },
#     "countries": [
#       "USA",
#       "Canada",
#       "Mexico"
#     ],
#     "cast": [
#       "Salma Hayek",
#       "M\u00e8a Maestro",
#       "Alfred Molina",
#       "Antonio Banderas"
#     ],
#     "directors": [
#       "Julie Taymor"
#     ],
#     "runtime": 123
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0f48"
#     },
#     "fullplot": "Jim West is a guns-a-blazing former Civil War hero. Artemus Gordon is an inventive U.S. Marshal who excels in disguise. When the United States is threatened by psychotic Confederate Arliss Loveless, President Ulysses Grant teams the duo up to bring him to justice. On a hazard-packed train journey from Washington D.C. to Utah, West and Gordon must combine their skills to best Loveless and his diabolical machines.",
#     "imdb": {
#       "rating": 4.8,
#       "votes": 122655,
#       "id": 120891
#     },
#     "year": 1999,
#     "plot": "The two best hired guns in the West must save President Grant from the clutches of a nineteenth-century inventor-villain.",
#     "genres": [
#       "Action",
#       "Western",
#       "Comedy"
#     ],
#     "rated": "PG-13",
#     "metacritic": 38,
#     "title": "Wild Wild West",
#     "lastupdated": "2015-09-10 17:48:40.287000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Jim Thomas (story)",
#       "John Thomas (story)",
#       "S.S. Wilson (screenplay)",
#       "Brent Maddock (screenplay)",
#       "Jeffrey Price (screenplay)",
#       "Peter S. Seaman (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://wildwildwest.warnerbros.com",
#       "viewer": {
#         "rating": 2.7,
#         "numReviews": 463636,
#         "meter": 28
#       },
#       "dvd": {
#         "$date": 943920000000
#       },
#       "critic": {
#         "rating": 4.1,
#         "numReviews": 130,
#         "meter": 17
#       },
#       "lastUpdated": {
#         "$date": 1442081682000
#       },
#       "consensus": "Bombastic, manic, and largely laugh-free, Wild Wild West is a bizarre misfire in which greater care was lavished upon the special effects than on the script.",
#       "rotten": 108,
#       "production": "Warner Bros. Pictures",
#       "fresh": 22
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYmYyMTc4YjItMGNhNC00OWQwLWJhMWUtNTdjZDgxMDI5MjE2L2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 2,
#     "released": {
#       "$date": 930700800000
#     },
#     "awards": {
#       "wins": 10,
#       "nominations": 11,
#       "text": "10 wins & 11 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Will Smith",
#       "Kevin Kline",
#       "Kenneth Branagh",
#       "Salma Hayek"
#     ],
#     "directors": [
#       "Barry Sonnenfeld"
#     ],
#     "runtime": 106
#   },
#   {
#     "_id": {
#       "$oid": "573a139bf29313caabcf3c57"
#     },
#     "plot": "Every Friday, the Colonel puts on his only suit and goes to the dock to await a letter announcing the arrival of his pension. But the townsfolk all know that this pension will never come. ...",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 118,
#     "cast": [
#       "Fernando Luj\u00e8n",
#       "Marisa Paredes",
#       "Salma Hayek",
#       "Rafael Incl\u00e8n"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTQxNjc2Njk1NV5BMl5BanBnXkFtZTcwOTY2MTU1MQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "No One Writes to the Colonel",
#     "fullplot": "Every Friday, the Colonel puts on his only suit and goes to the dock to await a letter announcing the arrival of his pension. But the townsfolk all know that this pension will never come. His wife also knows it, and even he knows it. But he is still waiting, living with the pain of the death of his son.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": 928281600000
#     },
#     "directors": [
#       "Arturo Ripstein"
#     ],
#     "writers": [
#       "Paz Alicia Garciadiego",
#       "Gabriel Garc\u00e8a M\u00e8rquez (novel)"
#     ],
#     "awards": {
#       "wins": 1,
#       "nominations": 2,
#       "text": "1 win & 2 nominations."
#     },
#     "lastupdated": "2015-07-30 00:34:51.927000000",
#     "year": 1999,
#     "imdb": {
#       "rating": 6.9,
#       "votes": 821,
#       "id": 132905
#     },
#     "countries": [
#       "Mexico",
#       "France",
#       "Spain"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.3,
#         "numReviews": 1004,
#         "meter": 62
#       },
#       "dvd": {
#         "$date": 1055203200000
#       },
#       "production": "Latin Crush",
#       "lastUpdated": {
#         "$date": 1442085702000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139ef29313caabcfba16"
#     },
#     "fullplot": "An anthology film retelling the story of the famous Studio 54, a hot disco hangout for the social elite of New York. The movie follows several characters at once, some of whom are in desperate straits and on the verge of crashing.",
#     "imdb": {
#       "rating": 5.8,
#       "votes": 26552,
#       "id": 120577
#     },
#     "year": 1998,
#     "plot": "Famous 70s NYC nightclub seen and told through the eyes of a young employee.",
#     "genres": [
#       "Drama",
#       "Music"
#     ],
#     "rated": "R",
#     "metacritic": 33,
#     "title": "54",
#     "lastupdated": "2015-08-30 02:17:08.113000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Mark Christopher"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/movie/54",
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 31237,
#         "meter": 44
#       },
#       "dvd": {
#         "$date": 986256000000
#       },
#       "critic": {
#         "rating": 4.2,
#         "numReviews": 66,
#         "meter": 15
#       },
#       "lastUpdated": {
#         "$date": 1440270591000
#       },
#       "consensus": "Poor plot development and slow pacing keep 54 from capturing the energy of it's legendary namesake.",
#       "rotten": 56,
#       "production": "Miramax Films",
#       "fresh": 10
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIzNzIxMjEtZDNiZS00Y2E1LTkwOTItZGJjOTMwYzU4YzVmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 1,
#     "released": {
#       "$date": 904262400000
#     },
#     "awards": {
#       "wins": 0,
#       "nominations": 7,
#       "text": "7 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Ryan Phillippe",
#       "Salma Hayek",
#       "Neve Campbell",
#       "Mike Myers"
#     ],
#     "directors": [
#       "Mark Christopher"
#     ],
#     "runtime": 93
#   },
#   {
#     "_id": {
#       "$oid": "573a13a4f29313caabd1276d"
#     },
#     "plot": "In the Time of the Butterflies is inspired by the true story of the three Mirabal sisters who, in 1960, were murdered for their part in an underground plot to overthrow the government.",
#     "genres": [
#       "Crime",
#       "Drama",
#       "History"
#     ],
#     "runtime": 95,
#     "rated": "PG-13",
#     "cast": [
#       "Salma Hayek",
#       "Edward James Olmos",
#       "M\u00e8a Maestro",
#       "Demian Bichir"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTQyNzc0NDExN15BMl5BanBnXkFtZTcwOTYwOTAyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "In the Time of the Butterflies",
#     "fullplot": "On November 25, 1960, the bodies of three sisters were found near the bottom of a cliff on the north coast of the Dominican Republic. The official daily 'El Caribe' reports that it had been an accident, but it does not mention that a fourth sister lives. Nor does it mention the sisters' fierce opposition to the General Trujillo's dictatorship. This is their story: how Minerva started the tragedy by refusing Trujillo; how Patria became an opponent from the church itself; how Maria Teresa joined the revolution through the love. And how they lost their wings, but not their courage. They were Las Mariposas - \"The Butterflies\".",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1092873600000
#     },
#     "directors": [
#       "Mariano Barroso"
#     ],
#     "writers": [
#       "Julia \u00e8lvarez (novel)",
#       "Judy Klass (teleplay)",
#       "David Klass (teleplay)"
#     ],
#     "awards": {
#       "wins": 2,
#       "nominations": 2,
#       "text": "2 wins & 2 nominations."
#     },
#     "lastupdated": "2015-08-28 00:32:45.503000000",
#     "year": 2001,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 1648,
#       "id": 263467
#     },
#     "countries": [
#       "USA",
#       "Mexico"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.8,
#         "numReviews": 3826,
#         "meter": 78
#       },
#       "dvd": {
#         "$date": 1020729600000
#       },
#       "production": "MGM",
#       "lastUpdated": {
#         "$date": 1437504796000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13a6f29313caabd17bd5"
#     },
#     "fullplot": "In the third movie of Rodriguez's \"Mariachi\" trilogy, a Mexican drug lord pretends to overthrow the Mexican government, and is connected to a corrupt CIA agent who at that time, demands retribution from his worst enemy to carry out the drug lord's uprising against the government.",
#     "imdb": {
#       "rating": 6.4,
#       "votes": 122029,
#       "id": 285823
#     },
#     "year": 2003,
#     "plot": "Hitman \"El Mariachi\" becomes involved in international espionage involving a psychotic CIA agent and a corrupt Mexican general.",
#     "genres": [
#       "Action",
#       "Thriller"
#     ],
#     "rated": "R",
#     "metacritic": 56,
#     "title": "Once Upon a Time in Mexico",
#     "lastupdated": "2015-09-07 00:09:02.457000000",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "writers": [
#       "Robert Rodriguez"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.sonypictures.com/movies/onceuponatimeinmexico/",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 284917,
#         "meter": 64
#       },
#       "dvd": {
#         "$date": 1074556800000
#       },
#       "critic": {
#         "rating": 6.3,
#         "numReviews": 163,
#         "meter": 68
#       },
#       "boxOffice": "$55.8M",
#       "consensus": "Violent, pulpy, loopy fun, with Depp stealing the show.",
#       "rotten": 52,
#       "production": "Sony Pictures Releasing",
#       "lastUpdated": {
#         "$date": 1442253796000
#       },
#       "fresh": 111
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTU5MDg5OTcwOV5BMl5BanBnXkFtZTcwMjI1MTIzMw@@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 2,
#     "released": {
#       "$date": 1063324800000
#     },
#     "awards": {
#       "wins": 3,
#       "nominations": 4,
#       "text": "3 wins & 4 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Johnny Depp",
#       "Mickey Rourke"
#     ],
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "runtime": 102
#   },
#   {
#     "_id": {
#       "$oid": "573a13adf29313caabd2af88"
#     },
#     "plot": "The story of what happens after a master thief achieves his last big score, when the FBI agent who promised he'd capture him is about to do just that.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Crime"
#     ],
#     "runtime": 97,
#     "metacritic": 38,
#     "rated": "PG-13",
#     "cast": [
#       "Pierce Brosnan",
#       "Salma Hayek",
#       "Woody Harrelson",
#       "Don Cheadle"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BN2YyMmE1MTUtNTg2OS00ZWRiLWFhZTQtZDViM2MyOGJhZDY3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "title": "After the Sunset",
#     "fullplot": "After a successful last score, a master thief retires to an island paradise. His lifelong nemesis, a crafty FBI agent, washes ashore to ensure he's making good on his promise. The pair soon enters into a new game of cat-and-mouse.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1100217600000
#     },
#     "directors": [
#       "Brett Ratner"
#     ],
#     "writers": [
#       "Paul Zbyszewski (story)",
#       "Paul Zbyszewski (screenplay)",
#       "Craig Rosenberg (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-21 00:50:02.187000000",
#     "year": 2004,
#     "imdb": {
#       "rating": 6.3,
#       "votes": 36636,
#       "id": 367479
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13aff29313caabd2f0a5"
#     },
#     "plot": "Mexican beauty Camilla hopes to rise above her station by marrying a wealthy American. That is complicated by meeting Arturo Bandini, a first-generation Italian hoping to land a writing career and a blue-eyed blonde on his arm.",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 117,
#     "metacritic": 58,
#     "rated": "R",
#     "cast": [
#       "Colin Farrell",
#       "Salma Hayek",
#       "Donald Sutherland",
#       "Eileen Atkins"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BZDc0ZWFmYjAtMTc2ZS00MzdlLThkZjAtM2I5ZGZlZjYzZDRlXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Ask the Dust",
#     "fullplot": "L.A. in the early 1930's: racism, poverty, and disease color the Bunker Hill neighborhood where Arturo Bandini, a lover of men and beasts alike, has arrived from Colorado to write the great Los Angeles novel. After six months and down to his last nickel, he orders a cup of coffee, served by Camilla Lopez, beautiful, self-possessed, and Mexican. Arturo gets advice, encouragement, and an occasional check from H.L. Mencken, so he keeps writing and he keeps seeing Camilla. But, he's mean to her for no apparent reason, so the relationship sputters. A housekeeper from back East suggests a way out of his jealously and fears. \"Camilla Bandini\": is it in the cards?",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": 1144886400000
#     },
#     "directors": [
#       "Robert Towne"
#     ],
#     "writers": [
#       "Robert Towne (screenplay)",
#       "John Fante (novel)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-14 01:31:42.053000000",
#     "year": 2006,
#     "imdb": {
#       "rating": 5.8,
#       "votes": 7690,
#       "id": 384814
#     },
#     "countries": [
#       "USA",
#       "Germany"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3c2c0"
#     },
#     "plot": "Based on the true story, two homicide detectives track Martha Beck and Raymond Martinez Fernandez, a murderous pair known as the \"Lonely Hearts Killers\" who lured their victims through the personals.",
#     "genres": [
#       "Crime",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 108,
#     "metacritic": 60,
#     "rated": "R",
#     "cast": [
#       "John Travolta",
#       "James Gandolfini",
#       "Jared Leto",
#       "Salma Hayek"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIxNGNjZTMtMGM5Ny00MmQ5LWEwODQtYTZkNGY2MjQ1MGM3XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Lonely Hearts",
#     "fullplot": "In the late 1940's, Martha Beck and Raymond Fernandez were America's notorious \"Lonely Hearts Killers\". Their lethal scam was simple; they would swindle and then viciously murder lovelorn war widows who would answer their personal ads in which Ray would describe himself as a sexy Latin Lover. Ironically, Ray's initial introduction to Martha was as a prospective mark. But when they met, it was love at first sight, perhaps as a result of their penchant for kinky sex and their mutual love for duplicity and easy money. With Martha posing as Ray's sister, they bilked elderly spinsters and widows of their savings and then viciously murdered them in a bloodbath of sexual frenzy. When they were arrested, Martha and Ray confessed to 12 killings, although it is believed the actual number is closer to 20. At their sensational trial, Martha and Ray cooed, held hands and seemed as though they could not get enough of each other. Their plea of not guilty by reason of insanity was rejected, and on August 22, 1949, the homicidal lovers were sentenced to death. After numerous appeals, they were electrocuted on March 8, 1951, side-by-side in Sing Sing prison.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1161388800000
#     },
#     "directors": [
#       "Todd Robinson"
#     ],
#     "writers": [
#       "Todd Robinson"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-28 00:31:01.910000000",
#     "year": 2006,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 16744,
#       "id": 441774
#     },
#     "countries": [
#       "Germany",
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.cstar.com/lonelyhearts/",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 9726,
#         "meter": 49
#       },
#       "dvd": {
#         "$date": 1185840000000
#       },
#       "critic": {
#         "rating": 5.6,
#         "numReviews": 42,
#         "meter": 48
#       },
#       "boxOffice": "$0.1M",
#       "consensus": "Several genres and plotlines intertwine in Lonely Hearts but don't connect, creating an uneven and unsatisfying film.",
#       "rotten": 22,
#       "production": "Samuel Goldwyn/Roadside",
#       "lastUpdated": {
#         "$date": 1440011573000
#       },
#       "fresh": 20
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3dccc"
#     },
#     "plot": "The events leading up to the sword fighting cat's meeting with Shrek and his friends.",
#     "genres": [
#       "Animation",
#       "Adventure",
#       "Comedy"
#     ],
#     "runtime": 90,
#     "metacritic": 65,
#     "rated": "PG",
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Zach Galifianakis",
#       "Billy Bob Thornton"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTMxMTU5MTY4MV5BMl5BanBnXkFtZTcwNzgyNjg2NQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Puss in Boots",
#     "fullplot": "Years before meeting Shrek and Donkey, the adorable but tricky Puss in Boots must clear his name from all charges making him a wanted fugitive. While trying to steal magic beans from the infamous criminals Jack and Jill, the hero crosses paths with his female match, Kitty Softpaws, who leads Puss to his old friend, but now enemy, Humpty Dumpty. Memories of friendship and betrayal enlarges Puss' doubt, but he eventually agrees to help the egg get the magic beans. Together, the three plan to steal the beans, get to the Giant's castle, nab the golden goose, and clear Puss' name.",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": 1319760000000
#     },
#     "directors": [
#       "Chris Miller"
#     ],
#     "writers": [
#       "Charles Perrault (character)",
#       "Tom Wheeler (screenplay)",
#       "Brian Lynch (story)",
#       "William Davies (story)",
#       "Tom Wheeler (story)"
#     ],
#     "awards": {
#       "wins": 7,
#       "nominations": 41,
#       "text": "Nominated for 1 Oscar. Another 6 wins & 41 nominations."
#     },
#     "lastupdated": "2015-08-23 00:38:10.813000000",
#     "year": 2011,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 104860,
#       "id": 448694
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.pussinbootsthemovie.com/",
#       "viewer": {
#         "rating": 3.6,
#         "numReviews": 77938,
#         "meter": 68
#       },
#       "dvd": {
#         "$date": 1330041600000
#       },
#       "critic": {
#         "rating": 6.8,
#         "numReviews": 142,
#         "meter": 84
#       },
#       "boxOffice": "$149.2M",
#       "consensus": "It isn't deep or groundbreaking, but what it lacks in profundity, Puss in Boots more than makes up for with an abundance of wit, visual sparkle, and effervescent charm.",
#       "rotten": 23,
#       "production": "Paramount/Dreamworks",
#       "lastUpdated": {
#         "$date": 1442081977000
#       },
#       "fresh": 119
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd82d05"
#     },
#     "plot": "Exiled artist and poet Mustafa embarks on a journey home with his housekeeper and her daughter; together the trio must evade the authorities who fear that the truth in Mustafa's words will incite rebellion.",
#     "genres": [
#       "Animation"
#     ],
#     "runtime": 84,
#     "metacritic": 61,
#     "rated": "PG",
#     "cast": [
#       "Salma Hayek",
#       "Liam Neeson",
#       "John Krasinski",
#       "Quvenzhan\u00e8 Wallis"
#     ],
#     "num_mflix_comments": 5,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTY5NzI4MjE2OV5BMl5BanBnXkFtZTgwMDg3OTU5NTE@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Prophet",
#     "fullplot": "Exiled artist and poet Mustafa embarks on a journey home with his housekeeper and her daughter; together the trio must evade the authorities who fear that the truth in Mustafa's words will incite rebellion.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1438905600000
#     },
#     "directors": [
#       "Roger Allers",
#       "Ga\u00e8tan Brizzi",
#       "Paul Brizzi",
#       "Joan C. Gratz",
#       "Mohammed Saeed Harib",
#       "Tomm Moore",
#       "Nina Paley",
#       "Bill Plympton",
#       "Joann Sfar",
#       "Michal Socha"
#     ],
#     "writers": [
#       "Roger Allers (screenplay)",
#       "Kahlil Gibran (novel)",
#       "Irene Mecchi (Additional Story & Dialogue)",
#       "Hanna Weg (additional writing)",
#       "Douglas Wood (additional story and dialogue)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 2,
#       "text": "2 nominations."
#     },
#     "lastupdated": "2015-08-29 00:02:18.623000000",
#     "year": 2014,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 618,
#       "id": 1640718
#     },
#     "countries": [
#       "USA",
#       "France",
#       "Canada",
#       "Lebanon",
#       "Qatar"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd833ed"
#     },
#     "plot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Sport"
#     ],
#     "runtime": 105,
#     "metacritic": 40,
#     "rated": "PG",
#     "cast": [
#       "Kevin James",
#       "Salma Hayek",
#       "Henry Winkler",
#       "Greg Germann"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTUxMzEzNDQ0Nl5BMl5BanBnXkFtZTcwMDI2NTY1OA@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Here Comes the Boom",
#     "fullplot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "languages": [
#       "English",
#       "Dutch"
#     ],
#     "released": {
#       "$date": 1350000000000
#     },
#     "directors": [
#       "Frank Coraci"
#     ],
#     "writers": [
#       "Allan Loeb",
#       "Kevin James"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-09-05 00:38:20.260000000",
#     "year": 2012,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 69939,
#       "id": 1648179
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13cff29313caabd88de0"
#     },
#     "plot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Sport"
#     ],
#     "runtime": 105,
#     "metacritic": 40,
#     "rated": "PG",
#     "cast": [
#       "Kevin James",
#       "Salma Hayek",
#       "Henry Winkler",
#       "Greg Germann"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTUxMzEzNDQ0Nl5BMl5BanBnXkFtZTcwMDI2NTY1OA@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Here Comes the Boom",
#     "fullplot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "languages": [
#       "English",
#       "Dutch"
#     ],
#     "released": {
#       "$date": 1350000000000
#     },
#     "directors": [
#       "Frank Coraci"
#     ],
#     "writers": [
#       "Allan Loeb",
#       "Kevin James"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-09-12 06:11:27.110000000",
#     "year": 2012,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 70090,
#       "id": 1648179
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13d1f29313caabd8ec00"
#     },
#     "plot": "An out-of-work publicist who suffers an accident looks to sell the exclusive interview rights to the highest bidder in an attempt to provide for his family.",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 94,
#     "metacritic": 32,
#     "cast": [
#       "Jos\u00e8 Mota",
#       "Salma Hayek",
#       "Blanca Portillo",
#       "Juan Luis Galiardo"
#     ],
#     "num_mflix_comments": 2,
#     "poster": "https://m.media-amazon.com/images/M/MV5BNzY4NTEyMjMzOF5BMl5BanBnXkFtZTcwNjEzNzIwOQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "As Luck Would Have It",
#     "fullplot": "An out-of-work publicist who suffers an accident looks to sell the exclusive interview rights to the highest bidder in an attempt to provide for his family.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": 1326412800000
#     },
#     "directors": [
#       "\u00e8lex de la Iglesia"
#     ],
#     "writers": [
#       "Randy Feldman (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-08-08 00:39:36.037000000",
#     "year": 2011,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 1786,
#       "id": 1808240
#     },
#     "countries": [
#       "Spain",
#       "France",
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.ifcfilms.com/films/as-luck-would-have-it",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 302,
#         "meter": 48
#       },
#       "critic": {
#         "rating": 4.6,
#         "numReviews": 5,
#         "meter": 40
#       },
#       "lastUpdated": {
#         "$date": 1434391346000
#       },
#       "rotten": 3,
#       "production": "Independent Pictures",
#       "fresh": 2
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13e9f29313caabdcc159"
#     },
#     "plot": "The film serves as Garrone's English-language debut and will interweave three separate story strands bookended by brief bits in which Italians Alba Rohrwacher and Massimo Ceccherini will ...",
#     "genres": [
#       "Fantasy",
#       "Romance"
#     ],
#     "runtime": 125,
#     "metacritic": 80,
#     "cast": [
#       "Salma Hayek",
#       "Vincent Cassel",
#       "Toby Jones",
#       "John C. Reilly"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BOTBiY2U2MTctNTA4Ni00MDBkLTk5MjItZWUxNDk5YmFlMTliL2ltYWdlXkEyXkFqcGdeQXVyNDUxNjc5NjY@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Tale of Tales",
#     "fullplot": "The film serves as Garrone's English-language debut and will interweave three separate story strands bookended by brief bits in which Italians Alba Rohrwacher and Massimo Ceccherini will play a street circus family. In one tale Salma Hayek will play a jealous queen who forfeits her husband's life. In another, Vincent Cassel plays a king whose passion is stoked by two mysterious sisters.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1431561600000
#     },
#     "directors": [
#       "Matteo Garrone"
#     ],
#     "writers": [
#       "Giambattista Basile (book)",
#       "Edoardo Albinati (screenplay)",
#       "Ugo Chiti (screenplay)",
#       "Matteo Garrone (screenplay)",
#       "Massimo Gaudioso (screenplay)"
#     ],
#     "awards": {
#       "wins": 3,
#       "nominations": 4,
#       "text": "3 wins & 4 nominations."
#     },
#     "lastupdated": "2015-09-01 00:07:19.663000000",
#     "year": 2015,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 1961,
#       "id": 3278330
#     },
#     "countries": [
#       "Italy",
#       "France",
#       "UK"
#     ],
#     "type": "movie"
#   }
# ]

# %%
# find all movies with Salma Hayek, but only project the "_id" and "title" fields
cursor = db.movies.find({"cast": "Salma Hayek"}, {"title": 1})
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabceea6d"
#     },
#     "title": "Roadracers"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef0b6"
#     },
#     "title": "Midaq Alley"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef179"
#     },
#     "title": "Desperado"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf092d"
#     },
#     "title": "Fools Rush In"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf09f1"
#     },
#     "title": "The Hunchback"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0e4f"
#     },
#     "title": "54"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0ea6"
#     },
#     "title": "Frida"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0f48"
#     },
#     "title": "Wild Wild West"
#   },
#   {
#     "_id": {
#       "$oid": "573a139bf29313caabcf3c57"
#     },
#     "title": "No One Writes to the Colonel"
#   },
#   {
#     "_id": {
#       "$oid": "573a139ef29313caabcfba16"
#     },
#     "title": "54"
#   },
#   {
#     "_id": {
#       "$oid": "573a13a4f29313caabd1276d"
#     },
#     "title": "In the Time of the Butterflies"
#   },
#   {
#     "_id": {
#       "$oid": "573a13a6f29313caabd17bd5"
#     },
#     "title": "Once Upon a Time in Mexico"
#   },
#   {
#     "_id": {
#       "$oid": "573a13adf29313caabd2af88"
#     },
#     "title": "After the Sunset"
#   },
#   {
#     "_id": {
#       "$oid": "573a13aff29313caabd2f0a5"
#     },
#     "title": "Ask the Dust"
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3c2c0"
#     },
#     "title": "Lonely Hearts"
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3dccc"
#     },
#     "title": "Puss in Boots"
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd82d05"
#     },
#     "title": "The Prophet"
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd833ed"
#     },
#     "title": "Here Comes the Boom"
#   },
#   {
#     "_id": {
#       "$oid": "573a13cff29313caabd88de0"
#     },
#     "title": "Here Comes the Boom"
#   },
#   {
#     "_id": {
#       "$oid": "573a13d1f29313caabd8ec00"
#     },
#     "title": "As Luck Would Have It"
#   },
#   {
#     "_id": {
#       "$oid": "573a13e9f29313caabdcc159"
#     },
#     "title": "Tale of Tales"
#   }
# ]

# %%
# find all movies with Salma Hayek, but only project the "title" field
cursor = db.movies.find({"cast": "Salma Hayek"}, {"title": 1, "_id": 0})
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "title": "Roadracers"
#   },
#   {
#     "title": "Midaq Alley"
#   },
#   {
#     "title": "Desperado"
#   },
#   {
#     "title": "Fools Rush In"
#   },
#   {
#     "title": "The Hunchback"
#   },
#   {
#     "title": "54"
#   },
#   {
#     "title": "Frida"
#   },
#   {
#     "title": "Wild Wild West"
#   },
#   {
#     "title": "No One Writes to the Colonel"
#   },
#   {
#     "title": "54"
#   },
#   {
#     "title": "In the Time of the Butterflies"
#   },
#   {
#     "title": "Once Upon a Time in Mexico"
#   },
#   {
#     "title": "After the Sunset"
#   },
#   {
#     "title": "Ask the Dust"
#   },
#   {
#     "title": "Lonely Hearts"
#   },
#   {
#     "title": "Puss in Boots"
#   },
#   {
#     "title": "The Prophet"
#   },
#   {
#     "title": "Here Comes the Boom"
#   },
#   {
#     "title": "Here Comes the Boom"
#   },
#   {
#     "title": "As Luck Would Have It"
#   },
#   {
#     "title": "Tale of Tales"
#   }
# ]

# %%
list(db.movies.aggregate([
            {'$match': {
                'countries': {'$in': ['USA', 'Hungary', 'Canada', 'France']}
            }},
            {'$project': {
                'title': 1
            }}
        ]))
# Out:
# [{'_id': ObjectId('573a1390f29313caabcd4135'), 'title': 'Blacksmith Scene'},
#  {'_id': ObjectId('573a1390f29313caabcd42e8'),
#   'title': 'The Great Train Robbery'},
#  {'_id': ObjectId('573a1390f29313caabcd4323'),
#   'title': 'The Land Beyond the Sunset'},
#  {'_id': ObjectId('573a1390f29313caabcd446f'), 'title': 'A Corner in Wheat'},
#  {'_id': ObjectId('573a1390f29313caabcd4803'),
#   'title': 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics'},
#  {'_id': ObjectId('573a1390f29313caabcd4eaf'), 'title': 'Traffic in Souls'},
#  {'_id': ObjectId('573a1390f29313caabcd50e5'), 'title': 'Gertie the Dinosaur'},
#  {'_id': ObjectId('573a1390f29313caabcd516c'),
#   'title': 'In the Land of the Head Hunters'},
#  {'_id': ObjectId('573a1390f29313caabcd5293'),
#   'title': 'The Perils of Pauline'},
#  {'_id': ObjectId('573a1390f29313caabcd548c'),
#   'title': 'The Birth of a Nation'},
#  {'_id': ObjectId('573a1390f29313caabcd5501'), 'title': 'The Cheat'},
#  {'_id': ObjectId('573a1390f29313caabcd56df'), 'title': 'The Italian'},
#  {'_id': ObjectId('573a1390f29313caabcd587d'), 'title': 'Regeneration'},
#  {'_id': ObjectId('573a1390f29313caabcd5967'), 'title': 'Les vampires'},
#  {'_id': ObjectId('573a1390f29313caabcd5a93'), 'title': 'Civilization'},
#  {'_id': ObjectId('573a1390f29313caabcd5b9a'), 'title': "Hell's Hinges"},
#  {'_id': ObjectId('573a1390f29313caabcd5c0f'),
#   'title': "Intolerance: Love's Struggle Throughout the Ages"},
#  {'_id': ObjectId('573a1390f29313caabcd5ea4'),
#   'title': 'Where Are My Children?'},
#  {'_id': ObjectId('573a1390f29313caabcd60e4'), 'title': 'The Immigrant'},
#  {'_id': ObjectId('573a1390f29313caabcd6223'),
#   'title': 'The Poor Little Rich Girl'},
#  {'_id': ObjectId('573a1390f29313caabcd6377'), 'title': 'Wild and Woolly'},
#  {'_id': ObjectId('573a1390f29313caabcd63d6'), 'title': 'The Blue Bird'},
#  {'_id': ObjectId('573a1390f29313caabcd680a'),
#   'title': 'Broken Blossoms or The Yellow Man and the Girl'},
#  {'_id': ObjectId('573a1391f29313caabcd68d0'), 'title': 'From Hand to Mouth'},
#  {'_id': ObjectId('573a1391f29313caabcd6d40'), 'title': 'High and Dizzy'},
#  {'_id': ObjectId('573a1391f29313caabcd6d90'),
#   'title': 'The Last of the Mohicans'},
#  {'_id': ObjectId('573a1391f29313caabcd6e2a'), 'title': 'One Week'},
#  {'_id': ObjectId('573a1391f29313caabcd6ea2'), 'title': 'The Saphead'},
#  {'_id': ObjectId('573a1391f29313caabcd6f98'), 'title': 'The Ace of Hearts'},
#  {'_id': ObjectId('573a1391f29313caabcd70b4'),
#   'title': 'The Four Horsemen of the Apocalypse'},
#  {'_id': ObjectId('573a1391f29313caabcd715c'), 'title': 'The Kid'},
#  {'_id': ObjectId('573a1391f29313caabcd71e3'), 'title': 'Miss Lulu Bett'},
#  {'_id': ObjectId('573a1391f29313caabcd71f5'), 'title': 'Now or Never'},
#  {'_id': ObjectId('573a1391f29313caabcd72f0'), 'title': "Tol'able David"},
#  {'_id': ObjectId('573a1391f29313caabcd73f4'), 'title': 'Cops'},
#  {'_id': ObjectId('573a1391f29313caabcd7472'), 'title': 'Foolish Wives'},
#  {'_id': ObjectId('573a1391f29313caabcd7586'), 'title': 'Nanook of the North'},
#  {'_id': ObjectId('573a1391f29313caabcd7616'), 'title': 'Salomè'},
#  {'_id': ObjectId('573a1391f29313caabcd7626'), 'title': 'Robin Hood'},
#  {'_id': ObjectId('573a1391f29313caabcd7850'),
#   'title': 'The Hunchback of Notre Dame'},
#  {'_id': ObjectId('573a1391f29313caabcd7915'), 'title': 'Our Hospitality'},
#  {'_id': ObjectId('573a1391f29313caabcd796e'), 'title': 'Safety Last!'},
#  {'_id': ObjectId('573a1391f29313caabcd79e4'), 'title': 'Three Ages'},
#  {'_id': ObjectId('573a1391f29313caabcd7a34'),
#   'title': 'A Woman of Paris: A Drama of Fate'},
#  {'_id': ObjectId('573a1391f29313caabcd7ac4'), 'title': 'The Chechahcos'},
#  {'_id': ObjectId('573a1391f29313caabcd7b98'), 'title': 'He Who Gets Slapped'},
#  {'_id': ObjectId('573a1391f29313caabcd7bc3'), 'title': 'The Iron Horse'},
#  {'_id': ObjectId('573a1391f29313caabcd7c4c'), 'title': 'The Navigator'},
#  {'_id': ObjectId('573a1391f29313caabcd7c9e'), 'title': 'Peter Pan'},
#  {'_id': ObjectId('573a1391f29313caabcd7d02'), 'title': 'Sherlock Jr.'},
#  {'_id': ObjectId('573a1391f29313caabcd7d4e'), 'title': 'The Thief of Bagdad'},
#  {'_id': ObjectId('573a1391f29313caabcd7da6'), 'title': 'Wild Oranges'},
#  {'_id': ObjectId('573a1391f29313caabcd7e23'), 'title': 'The Big Parade'},
#  {'_id': ObjectId('573a1391f29313caabcd7e6e'), 'title': 'Clash of the Wolves'},
#  {'_id': ObjectId('573a1391f29313caabcd7f07'), 'title': 'The Freshman'},
#  {'_id': ObjectId('573a1391f29313caabcd7f08'), 'title': 'Go West'},
#  {'_id': ObjectId('573a1391f29313caabcd7f11'),
#   'title': "Grass: A Nation's Battle for Life"},
#  {'_id': ObjectId('573a1391f29313caabcd7f19'), 'title': 'Greed'},
#  {'_id': ObjectId('573a1391f29313caabcd7f27'), 'title': 'The Gold Rush'},
#  {'_id': ObjectId('573a1391f29313caabcd7faa'),
#   'title': "Lady Windermere's Fan"},
#  {'_id': ObjectId('573a1391f29313caabcd7fb7'), 'title': 'The Lost World'},
#  {'_id': ObjectId('573a1391f29313caabcd806b'),
#   'title': 'The Phantom of the Opera'},
#  {'_id': ObjectId('573a1391f29313caabcd80db'), 'title': 'Seven Chances'},
#  {'_id': ObjectId('573a1391f29313caabcd820b'), 'title': 'Beau Geste'},
#  {'_id': ObjectId('573a1391f29313caabcd8210'), 'title': 'Battling Butler'},
#  {'_id': ObjectId('573a1391f29313caabcd821b'),
#   'title': 'Ben-Hur: A Tale of the Christ'},
#  {'_id': ObjectId('573a1391f29313caabcd8268'), 'title': 'The Black Pirate'},
#  {'_id': ObjectId('573a1391f29313caabcd82da'), 'title': 'Ella Cinders'},
#  {'_id': ObjectId('573a1391f29313caabcd830e'), 'title': 'Flesh and the Devil'},
#  {'_id': ObjectId('573a1391f29313caabcd8319'), 'title': "For Heaven's Sake"},
#  {'_id': ObjectId('573a1391f29313caabcd8521'),
#   'title': 'The Son of the Sheik'},
#  {'_id': ObjectId('573a1391f29313caabcd8543'), 'title': 'The Strong Man'},
#  {'_id': ObjectId('573a1391f29313caabcd8675'), 'title': 'College'},
#  {'_id': ObjectId('573a1391f29313caabcd8713'), 'title': 'The General'},
#  {'_id': ObjectId('573a1391f29313caabcd8780'), 'title': 'It'},
#  {'_id': ObjectId('573a1391f29313caabcd8783'), 'title': 'The Jazz Singer'},
#  {'_id': ObjectId('573a1391f29313caabcd8792'), 'title': 'The Kid Brother'},
#  {'_id': ObjectId('573a1391f29313caabcd883d'), 'title': 'Napoleon'},
#  {'_id': ObjectId('573a1391f29313caabcd88d8'), 'title': '7th Heaven'},
#  {'_id': ObjectId('573a1391f29313caabcd8945'), 'title': 'Sunrise'},
#  {'_id': ObjectId('573a1391f29313caabcd8978'), 'title': 'The Unknown'},
#  {'_id': ObjectId('573a1391f29313caabcd8979'), 'title': 'Upstream'},
#  {'_id': ObjectId('573a1391f29313caabcd89aa'), 'title': 'Wings'},
#  {'_id': ObjectId('573a1391f29313caabcd8a4c'), 'title': 'The Cameraman'},
#  {'_id': ObjectId('573a1391f29313caabcd8a75'), 'title': 'The Circus'},
#  {'_id': ObjectId('573a1391f29313caabcd8a82'), 'title': 'The Crowd'},
#  {'_id': ObjectId('573a1391f29313caabcd8aad'),
#   'title': 'The Docks of New York'},
#  {'_id': ObjectId('573a1391f29313caabcd8acf'),
#   'title': 'The Fall of the House of Usher'},
#  {'_id': ObjectId('573a1391f29313caabcd8ae8'), 'title': 'Four Sons'},
#  {'_id': ObjectId('573a1391f29313caabcd8b94'), 'title': 'The Last Command'},
#  {'_id': ObjectId('573a1391f29313caabcd8ba2'), 'title': 'Laugh, Clown, Laugh'},
#  {'_id': ObjectId('573a1391f29313caabcd8bb2'), 'title': 'Lonesome'},
#  {'_id': ObjectId('573a1391f29313caabcd8c57'),
#   'title': 'The Passion of Joan of Arc'},
#  {'_id': ObjectId('573a1391f29313caabcd8cbd'), 'title': 'Show People'},
#  {'_id': ObjectId('573a1391f29313caabcd8ce8'), 'title': 'Steamboat Bill, Jr.'},
#  {'_id': ObjectId('573a1391f29313caabcd8cef'), 'title': 'Street Angel'},
#  {'_id': ObjectId('573a1391f29313caabcd8cf4'), 'title': 'Steamboat Willie'},
#  {'_id': ObjectId('573a1391f29313caabcd8d7b'), 'title': 'The Wedding March'},
#  {'_id': ObjectId('573a1391f29313caabcd8d96'), 'title': 'The Wind'},
#  {'_id': ObjectId('573a1391f29313caabcd8dd1'), 'title': 'Applause'},
#  {'_id': ObjectId('573a1391f29313caabcd8e26'), 'title': 'The Broadway Melody'},
#  {'_id': ObjectId('573a1391f29313caabcd8e8f'), 'title': 'Disraeli'},
#  {'_id': ObjectId('573a1391f29313caabcd8e90'), 'title': 'The Divine Lady'},
#  {'_id': ObjectId('573a1391f29313caabcd8f04'), 'title': 'Hallelujah'},
#  {'_id': ObjectId('573a1391f29313caabcd8f66'), 'title': 'In Old Arizona'},
#  {'_id': ObjectId('573a1391f29313caabcd9053'), 'title': 'Queen Kelly'},
#  {'_id': ObjectId('573a1391f29313caabcd91b4'),
#   'title': 'All Quiet on the Western Front'},
#  {'_id': ObjectId('573a1391f29313caabcd91d7'), 'title': 'The Big House'},
#  {'_id': ObjectId('573a1391f29313caabcd91dc'), 'title': 'The Big Trail'},
#  {'_id': ObjectId('573a1391f29313caabcd9258'), 'title': 'David Golder'},
#  {'_id': ObjectId('573a1391f29313caabcd9264'), 'title': 'The Divorcee'},
#  {'_id': ObjectId('573a1391f29313caabcd9269'), 'title': 'The Devil to Pay!'},
#  {'_id': ObjectId('573a1391f29313caabcd9336'), 'title': 'King of Jazz'},
#  {'_id': ObjectId('573a1391f29313caabcd935e'), 'title': 'Little Caesar'},
#  {'_id': ObjectId('573a1391f29313caabcd93a3'), 'title': 'Men Without Women'},
#  {'_id': ObjectId('573a1391f29313caabcd93aa'), 'title': 'Morocco'},
#  {'_id': ObjectId('573a1391f29313caabcd944c'), 'title': 'Romance'},
#  {'_id': ObjectId('573a1391f29313caabcd9458'), 'title': 'The Blood of a Poet'},
#  {'_id': ObjectId('573a1391f29313caabcd94b1'),
#   'title': 'Under the Roofs of Paris'},
#  {'_id': ObjectId('573a1391f29313caabcd9596'), 'title': 'Bad Girl'},
#  {'_id': ObjectId('573a1391f29313caabcd95ee'), 'title': 'The Champ'},
#  {'_id': ObjectId('573a1391f29313caabcd95f6'), 'title': 'Cimarron'},
#  {'_id': ObjectId('573a1391f29313caabcd95fb'), 'title': 'City Streets'},
#  {'_id': ObjectId('573a1391f29313caabcd9600'), 'title': 'City Lights'},
#  {'_id': ObjectId('573a1391f29313caabcd962d'), 'title': 'Dishonored'},
#  {'_id': ObjectId('573a1391f29313caabcd9637'), 'title': 'Dracula'},
#  {'_id': ObjectId('573a1391f29313caabcd967e'), 'title': 'Frankenstein'},
#  {'_id': ObjectId('573a1391f29313caabcd9688'), 'title': 'A Free Soul'},
#  {'_id': ObjectId('573a1391f29313caabcd96ac'), 'title': 'The Guardsman'},
#  {'_id': ObjectId('573a1391f29313caabcd96ae'), 'title': 'The Front Page'},
#  {'_id': ObjectId('573a1391f29313caabcd9721'), 'title': 'Comradeship'},
#  {'_id': ObjectId('573a1392f29313caabcd97ee'),
#   'title': "L'opèra de quat'sous"},
#  {'_id': ObjectId('573a1392f29313caabcd980d'), 'title': 'The Public Enemy'},
#  {'_id': ObjectId('573a1392f29313caabcd9871'),
#   'title': 'The Sin of Madelon Claudet'},
#  {'_id': ObjectId('573a1392f29313caabcd987c'), 'title': 'Skippy'},
#  {'_id': ObjectId('573a1392f29313caabcd98c3'),
#   'title': 'Tabu: A Story of the South Seas'},
#  {'_id': ObjectId('573a1392f29313caabcd9950'), 'title': 'è Nous la Libertè'},
#  {'_id': ObjectId('573a1392f29313caabcd99e3'), 'title': 'Broken Lullaby'},
#  {'_id': ObjectId('573a1392f29313caabcd9a10'), 'title': 'The Crowd Roars'},
#  {'_id': ObjectId('573a1392f29313caabcd9a3b'),
#   'title': 'Dr. Jekyll and Mr. Hyde'},
#  {'_id': ObjectId('573a1392f29313caabcd9a5d'), 'title': 'A Farewell to Arms'},
#  {'_id': ObjectId('573a1392f29313caabcd9a76'), 'title': 'Forbidden'},
#  {'_id': ObjectId('573a1392f29313caabcd9a7e'), 'title': 'Freaks'},
#  {'_id': ObjectId('573a1392f29313caabcd9aab'), 'title': 'Grand Hotel'},
#  {'_id': ObjectId('573a1392f29313caabcd9aff'),
#   'title': 'I Am a Fugitive from a Chain Gang'},
#  {'_id': ObjectId('573a1392f29313caabcd9b93'), 'title': 'Love Me Tonight'},
#  {'_id': ObjectId('573a1392f29313caabcd9bcf'),
#   'title': 'Murders in the Rue Morgue'},
#  {'_id': ObjectId('573a1392f29313caabcd9be6'), 'title': 'The Mummy'},
#  {'_id': ObjectId('573a1392f29313caabcd9bf5'), 'title': 'Movie Crazy'},
#  {'_id': ObjectId('573a1392f29313caabcd9bf8'), 'title': 'The Music Box'},
#  {'_id': ObjectId('573a1392f29313caabcd9c1b'), 'title': 'Payment Deferred'},
#  {'_id': ObjectId('573a1392f29313caabcd9c4c'), 'title': 'The Red Head'},
#  {'_id': ObjectId('573a1392f29313caabcd9c5d'), 'title': 'Red Dust'},
#  {'_id': ObjectId('573a1392f29313caabcd9ca6'), 'title': 'Scarface'},
#  {'_id': ObjectId('573a1392f29313caabcd9caa'), 'title': 'Shanghai Express'},
#  {'_id': ObjectId('573a1392f29313caabcd9cce'), 'title': "Smilin' Through"},
#  {'_id': ObjectId('573a1392f29313caabcd9cfb'), 'title': 'Tarzan the Ape Man'},
#  {'_id': ObjectId('573a1392f29313caabcd9d4a'), 'title': 'Two Seconds'},
#  {'_id': ObjectId('573a1392f29313caabcd9d4c'), 'title': 'Trouble in Paradise'},
#  {'_id': ObjectId('573a1392f29313caabcd9dee'), 'title': 'Baby Face'},
#  {'_id': ObjectId('573a1392f29313caabcd9df7'), 'title': 'Berkeley Square'},
#  {'_id': ObjectId('573a1392f29313caabcd9e3e'), 'title': 'Cavalcade'},
#  {'_id': ObjectId('573a1392f29313caabcd9e9b'), 'title': 'Duck Soup'},
#  {'_id': ObjectId('573a1392f29313caabcd9eb0'), 'title': 'Eskimo'},
#  {'_id': ObjectId('573a1392f29313caabcd9ed7'), 'title': 'Footlight Parade'},
#  {'_id': ObjectId('573a1392f29313caabcd9ee7'), 'title': '42nd Street'},
#  {'_id': ObjectId('573a1392f29313caabcd9ee9'), 'title': 'Flying Down to Rio'},
#  {'_id': ObjectId('573a1392f29313caabcd9f00'), 'title': 'The Emperor Jones'},
#  {'_id': ObjectId('573a1392f29313caabcd9f01'),
#   'title': 'Gold Diggers of 1933'},
#  {'_id': ObjectId('573a1392f29313caabcd9f09'), 'title': 'Going Hollywood'},
#  {'_id': ObjectId('573a1392f29313caabcd9f7e'), 'title': 'The Invisible Man'},
#  {'_id': ObjectId('573a1392f29313caabcd9f92'), 'title': 'King Kong'},
#  {'_id': ObjectId('573a1392f29313caabcd9fc4'), 'title': 'Little Women'},
#  {'_id': ObjectId('573a1392f29313caabcda094'),
#   'title': 'The Power and the Glory'},
#  {'_id': ObjectId('573a1392f29313caabcda0a5'), 'title': 'Queen Christina'},
#  {'_id': ObjectId('573a1392f29313caabcda0e7'), 'title': 'She Done Him Wrong'},
#  {'_id': ObjectId('573a1392f29313caabcda111'), 'title': 'Sons of the Desert'},
#  {'_id': ObjectId('573a1392f29313caabcda114'), 'title': 'The Son of Kong'},
#  {'_id': ObjectId('573a1392f29313caabcda126'), 'title': 'State Fair'},
#  {'_id': ObjectId('573a1392f29313caabcda162'), 'title': 'Three Little Pigs'},
#  {'_id': ObjectId('573a1392f29313caabcda16f'), 'title': 'Topaze'},
#  {'_id': ObjectId('573a1392f29313caabcda1d2'),
#   'title': 'Wild Boys of the Road'},
#  {'_id': ObjectId('573a1392f29313caabcda1e3'), 'title': 'Zoo in Budapest'},
#  {'_id': ObjectId('573a1392f29313caabcda206'), 'title': 'Zero for Conduct'},
#  {'_id': ObjectId('573a1392f29313caabcda224'),
#   'title': 'The Barretts of Wimpole Street'},
#  {'_id': ObjectId('573a1392f29313caabcda241'), 'title': 'The Black Cat'},
#  {'_id': ObjectId('573a1392f29313caabcda262'), 'title': 'Broadway Bill'},
#  {'_id': ObjectId('573a1392f29313caabcda2a2'), 'title': 'Cleopatra'},
#  {'_id': ObjectId('573a1392f29313caabcda2a4'),
#   'title': 'The Count of Monte Cristo'},
#  {'_id': ObjectId('573a1392f29313caabcda2c5'),
#   'title': 'Death Takes a Holiday'},
#  {'_id': ObjectId('573a1392f29313caabcda2c7'), 'title': 'Dames'},
#  {'_id': ObjectId('573a1392f29313caabcda34f'), 'title': 'The Gay Divorcee'},
#  {'_id': ObjectId('573a1392f29313caabcda391'), 'title': 'Le grand jeu'},
#  {'_id': ObjectId('573a1392f29313caabcda3ce'), 'title': 'Imitation of Life'},
#  {'_id': ObjectId('573a1392f29313caabcda3dc'),
#   'title': 'It Happened One Night'},
#  {'_id': ObjectId('573a1392f29313caabcda3e9'), 'title': "It's a Gift"},
#  {'_id': ObjectId('573a1392f29313caabcda43a'), 'title': 'Little Miss Marker'},
#  {'_id': ObjectId('573a1392f29313caabcda451'), 'title': 'The Lost Patrol'},
#  {'_id': ObjectId('573a1392f29313caabcda477'), 'title': 'Maria Chapdelaine'},
#  {'_id': ObjectId('573a1392f29313caabcda4a9'), 'title': 'Les Misèrables'},
#  {'_id': ObjectId('573a1392f29313caabcda515'), 'title': 'One Night of Love'},
#  {'_id': ObjectId('573a1392f29313caabcda594'), 'title': 'The Scarlet Empress'},
#  {'_id': ObjectId('573a1392f29313caabcda5fe'), 'title': 'Tarzan and His Mate'},
#  {'_id': ObjectId('573a1392f29313caabcda619'), 'title': 'The Thin Man'},
#  {'_id': ObjectId('573a1392f29313caabcda636'), 'title': 'Toni'},
#  {'_id': ObjectId('573a1392f29313caabcda64c'), 'title': 'Twentieth Century'},
#  {'_id': ObjectId('573a1392f29313caabcda654'), 'title': 'Viva Villa!'},
#  {'_id': ObjectId('573a1392f29313caabcda6aa'), 'title': 'The World Moves On'},
#  {'_id': ObjectId('573a1392f29313caabcda6b3'), 'title': 'Wonder Bar'},
#  {'_id': ObjectId('573a1392f29313caabcda6e1'), 'title': 'Anna Karenina'},
#  {'_id': ObjectId('573a1392f29313caabcda6f1'), 'title': 'The Band Concert'},
#  {'_id': ObjectId('573a1392f29313caabcda6f4'), 'title': 'Becky Sharp'},
#  {'_id': ObjectId('573a1392f29313caabcda6f7'), 'title': 'Alice Adams'},
#  {'_id': ObjectId('573a1392f29313caabcda70a'), 'title': 'Black Fury'},
#  {'_id': ObjectId('573a1392f29313caabcda713'),
#   'title': 'Bride of Frankenstein'},
#  {'_id': ObjectId('573a1392f29313caabcda722'),
#   'title': 'Broadway Melody of 1936'},
#  {'_id': ObjectId('573a1392f29313caabcda755'), 'title': 'China Seas'},
#  {'_id': ObjectId('573a1392f29313caabcda781'), 'title': 'Curly Top'},
#  {'_id': ObjectId('573a1392f29313caabcda78f'), 'title': "Dante's Inferno"},
#  {'_id': ObjectId('573a1392f29313caabcda792'), 'title': 'The Crusades'},
#  {'_id': ObjectId('573a1392f29313caabcda79a'), 'title': 'David Copperfield'},
#  {'_id': ObjectId('573a1392f29313caabcda7a1'), 'title': 'The Dark Angel'},
#  {'_id': ObjectId('573a1392f29313caabcda7a4'),
#   'title': 'The Devil Is a Woman'},
#  {'_id': ObjectId('573a1392f29313caabcda7fb'),
#   'title': 'Folies Bergère de Paris'},
#  {'_id': ObjectId('573a1392f29313caabcda81f'), 'title': 'The Gilded Lily'},
#  {'_id': ObjectId('573a1392f29313caabcda82b'),
#   'title': 'Gold Diggers of 1935'},
#  {'_id': ObjectId('573a1392f29313caabcda896'), 'title': 'The Informer'},
#  {'_id': ObjectId('573a1392f29313caabcda8c3'),
#   'title': 'Carnival in Flanders'},
#  {'_id': ObjectId('573a1392f29313caabcda930'),
#   'title': 'The Lives of a Bengal Lancer'},
#  {'_id': ObjectId('573a1392f29313caabcda959'),
#   'title': "A Midsummer Night's Dream"},
#  {'_id': ObjectId('573a1392f29313caabcda964'), 'title': 'Les Misèrables'},
#  {'_id': ObjectId('573a1392f29313caabcda974'),
#   'title': 'Mutiny on the Bounty'},
#  {'_id': ObjectId('573a1392f29313caabcda98f'), 'title': 'Naughty Marietta'},
#  {'_id': ObjectId('573a1392f29313caabcda998'),
#   'title': 'A Night at the Opera'},
#  {'_id': ObjectId('573a1392f29313caabcdaa3c'), 'title': 'Roberta'},
#  {'_id': ObjectId('573a1392f29313caabcdaa3e'), 'title': 'Ruggles of Red Gap'},
#  {'_id': ObjectId('573a1392f29313caabcdaa70'), 'title': 'She'},
#  {'_id': ObjectId('573a1392f29313caabcdaae8'), 'title': 'Top Hat'},
#  {'_id': ObjectId('573a1392f29313caabcdab28'), 'title': 'The Wedding Night'},
#  {'_id': ObjectId('573a1392f29313caabcdab4a'),
#   'title': 'Who Killed Cock Robin?'},
#  {'_id': ObjectId('573a1392f29313caabcdab98'), 'title': 'Anthony Adverse'},
#  {'_id': ObjectId('573a1392f29313caabcdabc6'), 'title': 'The Lower Depths'},
#  {'_id': ObjectId('573a1392f29313caabcdabdd'), 'title': 'Black Legion'},
#  {'_id': ObjectId('573a1392f29313caabcdac22'),
#   'title': 'The Charge of the Light Brigade'},
#  {'_id': ObjectId('573a1392f29313caabcdac43'), 'title': 'Come and Get It'},
#  {'_id': ObjectId('573a1392f29313caabcdac95'), 'title': 'Dodsworth'},
#  {'_id': ObjectId('573a1392f29313caabcdace2'), 'title': 'Follow the Fleet'},
#  {'_id': ObjectId('573a1392f29313caabcdacf0'), 'title': 'Flash Gordon'},
#  {'_id': ObjectId('573a1392f29313caabcdacf8'), 'title': 'Fury'},
#  {'_id': ObjectId('573a1392f29313caabcdad11'), 'title': 'The Garden of Allah'},
#  {'_id': ObjectId('573a1392f29313caabcdad30'), 'title': 'The Great Ziegfeld'},
#  {'_id': ObjectId('573a1392f29313caabcdad3c'), 'title': 'The Green Pastures'},
#  {'_id': ObjectId('573a1392f29313caabcdad95'), 'title': 'The Invisible Ray'},
#  {'_id': ObjectId('573a1392f29313caabcdadf0'), 'title': "Lloyd's of London"},
#  {'_id': ObjectId('573a1392f29313caabcdae1e'), 'title': 'Mary of Scotland'},
#  {'_id': ObjectId('573a1392f29313caabcdae3d'), 'title': 'Modern Times'},
#  {'_id': ObjectId('573a1392f29313caabcdae43'), 'title': 'Mayerling'},
#  {'_id': ObjectId('573a1392f29313caabcdae4f'),
#   'title': 'Mr. Deeds Goes to Town'},
#  {'_id': ObjectId('573a1392f29313caabcdae5e'), 'title': 'My Man Godfrey'},
#  {'_id': ObjectId('573a1392f29313caabcdaeca'),
#   'title': 'Popeye the Sailor Meets Sindbad the Sailor'},
#  {'_id': ObjectId('573a1392f29313caabcdaee0'),
#   'title': 'The Prisoner of Shark Island'},
#  {'_id': ObjectId('573a1392f29313caabcdaf1c'),
#   'title': 'The Story of a Cheat'},
#  {'_id': ObjectId('573a1392f29313caabcdaf28'), 'title': 'Romeo and Juliet'},
#  {'_id': ObjectId('573a1392f29313caabcdaf75'), 'title': 'San Francisco'},
#  {'_id': ObjectId('573a1392f29313caabcdaf8c'),
#   'title': 'The Story of Louis Pasteur'},
#  {'_id': ObjectId('573a1392f29313caabcdafa2'), 'title': 'Swing Time'},
#  {'_id': ObjectId('573a1392f29313caabcdafc1'), 'title': 'These Three'},
#  {'_id': ObjectId('573a1392f29313caabcdafca'), 'title': 'Theodora Goes Wild'},
#  {'_id': ObjectId('573a1392f29313caabcdafdb'), 'title': 'Three Smart Girls'},
#  {'_id': ObjectId('573a1392f29313caabcdafe6'),
#   'title': 'The Trail of the Lonesome Pine'},
#  {'_id': ObjectId('573a1392f29313caabcdb012'),
#   'title': 'A Day in the Country'},
#  {'_id': ObjectId('573a1392f29313caabcdb0bd'), 'title': 'The Awful Truth'},
#  {'_id': ObjectId('573a1392f29313caabcdb108'), 'title': 'Camille'},
#  {'_id': ObjectId('573a1392f29313caabcdb11c'), 'title': 'Captains Courageous'},
#  {'_id': ObjectId('573a1392f29313caabcdb148'),
#   'title': 'A Damsel in Distress'},
#  {'_id': ObjectId('573a1392f29313caabcdb155'),
#   'title': 'Daughter of Shanghai'},
#  {'_id': ObjectId('573a1392f29313caabcdb208'), 'title': 'La Grande Illusion'},
#  {'_id': ObjectId('573a1392f29313caabcdb20d'), 'title': 'The Good Earth'},
#  {'_id': ObjectId('573a1392f29313caabcdb231'), 'title': 'Harvest'},
#  {'_id': ObjectId('573a1392f29313caabcdb258'), 'title': 'The Hurricane'},
#  {'_id': ObjectId('573a1392f29313caabcdb27d'), 'title': 'In Old Chicago'},
#  {'_id': ObjectId('573a1392f29313caabcdb295'), 'title': 'Kid Galahad'},
#  {'_id': ObjectId('573a1392f29313caabcdb2cd'),
#   'title': 'The Life of Emile Zola'},
#  {'_id': ObjectId('573a1392f29313caabcdb2dc'), 'title': 'Lost Horizon'},
#  {'_id': ObjectId('573a1392f29313caabcdb2fb'),
#   'title': 'Make Way for Tomorrow'},
#  {'_id': ObjectId('573a1392f29313caabcdb314'), 'title': 'Marked Woman'},
#  {'_id': ObjectId('573a1392f29313caabcdb397'), 'title': 'Night Must Fall'},
#  {'_id': ObjectId('573a1392f29313caabcdb3aa'),
#   'title': 'One Hundred Men and a Girl'},
#  {'_id': ObjectId('573a1392f29313caabcdb3c7'),
#   'title': 'The Pearls of the Crown'},
#  {'_id': ObjectId('573a1392f29313caabcdb3f2'),
#   'title': 'The Prince and the Pauper'},
#  {'_id': ObjectId('573a1392f29313caabcdb3f4'),
#   'title': 'The Prisoner of Zenda'},
#  {'_id': ObjectId('573a1392f29313caabcdb40b'), 'title': 'Pèpè le Moko'},
#  {'_id': ObjectId('573a1392f29313caabcdb47e'), 'title': 'Shall We Dance'},
#  {'_id': ObjectId('573a1392f29313caabcdb48b'),
#   'title': 'Snow White and the Seven Dwarfs'},
#  {'_id': ObjectId('573a1392f29313caabcdb495'), 'title': 'Stage Door'},
#  {'_id': ObjectId('573a1392f29313caabcdb496'), 'title': 'The Spanish Earth'},
#  {'_id': ObjectId('573a1392f29313caabcdb497'), 'title': 'A Star Is Born'},
#  {'_id': ObjectId('573a1392f29313caabcdb4d5'), 'title': "They Won't Forget"},
#  {'_id': ObjectId('573a1392f29313caabcdb4ee'), 'title': 'This Is My Affair'},
#  {'_id': ObjectId('573a1392f29313caabcdb505'), 'title': 'Dance Program'},
#  {'_id': ObjectId('573a1392f29313caabcdb529'), 'title': 'Waikiki Wedding'},
#  {'_id': ObjectId('573a1392f29313caabcdb585'),
#   'title': 'The Adventures of Robin Hood'},
#  {'_id': ObjectId('573a1392f29313caabcdb58d'),
#   'title': 'The Adventures of Tom Sawyer'},
#  {'_id': ObjectId('573a1392f29313caabcdb590'), 'title': 'Algiers'},
#  {'_id': ObjectId('573a1392f29313caabcdb5a9'),
#   'title': 'Angels with Dirty Faces'},
#  {'_id': ObjectId('573a1392f29313caabcdb5ab'),
#   'title': "Alexander's Ragtime Band"},
#  {'_id': ObjectId('573a1392f29313caabcdb5cb'),
#   'title': 'The Big Broadcast of 1938'},
#  {'_id': ObjectId('573a1392f29313caabcdb5ef'), 'title': 'Bringing Up Baby'},
#  {'_id': ObjectId('573a1392f29313caabcdb5fc'), 'title': 'Boys Town'},
#  {'_id': ObjectId('573a1392f29313caabcdb600'), 'title': 'La Bète Humaine'},
#  {'_id': ObjectId('573a1392f29313caabcdb618'), 'title': 'Carefree'},
#  {'_id': ObjectId('573a1392f29313caabcdb646'),
#   'title': 'The Cowboy and the Lady'},
#  {'_id': ObjectId('573a1392f29313caabcdb69f'), 'title': "The Baker's Wife"},
#  {'_id': ObjectId('573a1392f29313caabcdb6c0'), 'title': 'Four Daughters'},
#  {'_id': ObjectId('573a1392f29313caabcdb700'), 'title': 'The Great Waltz'},
#  {'_id': ObjectId('573a1392f29313caabcdb73c'), 'title': 'Hotel du Nord'},
#  {'_id': ObjectId('573a1392f29313caabcdb73e'), 'title': 'Jezebel'},
#  {'_id': ObjectId('573a1392f29313caabcdb7b7'),
#   'title': 'Love Finds Andy Hardy'},
#  {'_id': ObjectId('573a1392f29313caabcdb7b9'), 'title': 'A Man to Remember'},
#  {'_id': ObjectId('573a1392f29313caabcdb7c1'), 'title': 'Marie Antoinette'},
#  {'_id': ObjectId('573a1392f29313caabcdb7ef'),
#   'title': "Mother Carey's Chickens"},
#  {'_id': ObjectId('573a1392f29313caabcdb82f'), 'title': 'Of Human Hearts'},
#  {'_id': ObjectId('573a1392f29313caabcdb8ac'), 'title': 'Port of Shadows'},
#  {'_id': ObjectId('573a1392f29313caabcdb8b5'), 'title': 'The Rage of Paris'},
#  {'_id': ObjectId('573a1392f29313caabcdb94f'), 'title': 'Sweethearts'},
#  {'_id': ObjectId('573a1392f29313caabcdb970'), 'title': 'Test Pilot'},
#  {'_id': ObjectId('573a1392f29313caabcdb980'), 'title': 'Three Comrades'},
#  {'_id': ObjectId('573a1392f29313caabcdb9a1'), 'title': 'Too Much Johnson'},
#  {'_id': ObjectId('573a1392f29313caabcdb9eb'), 'title': 'White Banners'},
#  {'_id': ObjectId('573a1392f29313caabcdb9ff'),
#   'title': "You Can't Take It With You"},
#  {'_id': ObjectId('573a1392f29313caabcdba01'), 'title': 'You and Me'},
#  {'_id': ObjectId('573a1392f29313caabcdba09'), 'title': 'Vivacious Lady'},
#  {'_id': ObjectId('573a1392f29313caabcdbabd'),
#   'title': 'Confessions of a Nazi Spy'},
#  {'_id': ObjectId('573a1392f29313caabcdbad6'), 'title': 'Dark Victory'},
#  {'_id': ObjectId('573a1392f29313caabcdbaef'), 'title': 'Destry Rides Again'},
#  {'_id': ObjectId('573a1392f29313caabcdbb45'), 'title': 'La fin du jour'},
#  {'_id': ObjectId('573a1392f29313caabcdbb8a'), 'title': 'Gone with the Wind'},
#  {'_id': ObjectId('573a1392f29313caabcdbbae'), 'title': 'Gunga Din'},
#  {'_id': ObjectId('573a1392f29313caabcdbc0f'), 'title': 'Le Jour se Leve'},
#  {'_id': ObjectId('573a1392f29313caabcdbc89'), 'title': 'Midnight'},
#  {'_id': ObjectId('573a1392f29313caabcdbcbc'),
#   'title': 'Mr. Smith Goes to Washington'},
#  {'_id': ObjectId('573a1392f29313caabcdbceb'), 'title': 'Ninotchka'},
#  {'_id': ObjectId('573a1392f29313caabcdbd07'), 'title': 'Of Mice and Men'},
#  {'_id': ObjectId('573a1392f29313caabcdbd59'), 'title': 'The Rains Came'},
#  {'_id': ObjectId('573a1392f29313caabcdbd65'),
#   'title': 'The Roaring Twenties'},
#  {'_id': ObjectId('573a1392f29313caabcdbd80'),
#   'title': 'The Rules of the Game'},
#  {'_id': ObjectId('573a1392f29313caabcdbdce'), 'title': 'Stagecoach'},
#  {'_id': ObjectId('573a1392f29313caabcdbde3'),
#   'title': 'The Story of Vernon and Irene Castle'},
#  {'_id': ObjectId('573a1392f29313caabcdbe09'), 'title': 'Tevya'},
#  {'_id': ObjectId('573a1393f29313caabcdbe46'), 'title': 'Union Pacific'},
#  {'_id': ObjectId('573a1393f29313caabcdbe7c'), 'title': 'The Wizard of Oz'},
#  {'_id': ObjectId('573a1393f29313caabcdbe83'), 'title': 'The Women'},
#  {'_id': ObjectId('573a1393f29313caabcdbe85'), 'title': 'Wuthering Heights'},
#  {'_id': ObjectId('573a1393f29313caabcdbe8f'), 'title': 'Young Mr. Lincoln'},
#  {'_id': ObjectId('573a1393f29313caabcdbed0'), 'title': 'Arise, My Love'},
#  {'_id': ObjectId('573a1393f29313caabcdbed5'), 'title': 'The Bank Dick'},
#  {'_id': ObjectId('573a1393f29313caabcdbef1'), 'title': 'The Biscuit Eater'},
#  {'_id': ObjectId('573a1393f29313caabcdbef6'), 'title': 'Black Friday'},
#  {'_id': ObjectId('573a1393f29313caabcdbf6c'), 'title': 'Dance, Girl, Dance'},
#  {'_id': ObjectId('573a1393f29313caabcdbf81'), 'title': 'Dots'},
#  {'_id': ObjectId('573a1393f29313caabcdbf82'), 'title': 'Down Argentine Way'},
#  {'_id': ObjectId('573a1393f29313caabcdbfb0'), 'title': 'Fantasia'},
#  {'_id': ObjectId('573a1393f29313caabcdbfcc'),
#   'title': 'Foreign Correspondent'},
#  {'_id': ObjectId('573a1393f29313caabcdc01a'), 'title': 'The Grapes of Wrath'},
#  {'_id': ObjectId('573a1393f29313caabcdc030'), 'title': 'The Great Dictator'},
#  {'_id': ObjectId('573a1393f29313caabcdc04b'), 'title': 'His Girl Friday'},
#  {'_id': ObjectId('573a1393f29313caabcdc093'), 'title': 'Kitty Foyle'},
#  {'_id': ObjectId('573a1393f29313caabcdc0a0'),
#   'title': 'Knute Rockne All American'},
#  {'_id': ObjectId('573a1393f29313caabcdc0bb'), 'title': 'The Letter'},
#  {'_id': ObjectId('573a1393f29313caabcdc0cb'),
#   'title': 'The Long Voyage Home'},
#  {'_id': ObjectId('573a1393f29313caabcdc0f7'), 'title': 'The Mark of Zorro'},
#  {'_id': ObjectId('573a1393f29313caabcdc150'),
#   'title': 'North West Mounted Police'},
#  {'_id': ObjectId('573a1393f29313caabcdc159'), 'title': 'Our Town'},
#  {'_id': ObjectId('573a1393f29313caabcdc16f'),
#   'title': 'The Philadelphia Story'},
#  {'_id': ObjectId('573a1393f29313caabcdc180'), 'title': 'Pinocchio'},
#  {'_id': ObjectId('573a1393f29313caabcdc1c2'), 'title': 'Rebecca'},
#  {'_id': ObjectId('573a1393f29313caabcdc207'),
#   'title': 'The Shop Around the Corner'},
#  {'_id': ObjectId('573a1393f29313caabcdc23e'), 'title': 'Strike Up the Band'},
#  {'_id': ObjectId('573a1393f29313caabcdc2e2'), 'title': 'The Westerner'},
#  {'_id': ObjectId('573a1393f29313caabcdc364'), 'title': 'Blood and Sand'},
#  {'_id': ObjectId('573a1393f29313caabcdc370'), 'title': 'The Blood of Jesus'},
#  {'_id': ObjectId('573a1393f29313caabcdc371'),
#   'title': 'Blossoms in the Dust'},
#  {'_id': ObjectId('573a1393f29313caabcdc3a3'), 'title': 'Citizen Kane'},
#  {'_id': ObjectId('573a1393f29313caabcdc3f7'),
#   'title': 'The Devil and Daniel Webster'},
#  {'_id': ObjectId('573a1393f29313caabcdc403'), 'title': 'Dumbo'},
#  {'_id': ObjectId('573a1393f29313caabcdc435'),
#   'title': "The Well-Digger's Daughter"},
#  {'_id': ObjectId('573a1393f29313caabcdc4a2'),
#   'title': 'Here Comes Mr. Jordan'},
#  {'_id': ObjectId('573a1393f29313caabcdc4a8'), 'title': 'High Sierra'},
#  {'_id': ObjectId('573a1393f29313caabcdc4b3'),
#   'title': 'How Green Was My Valley'},
#  {'_id': ObjectId('573a1393f29313caabcdc4b6'), 'title': 'Hold Back the Dawn'},
#  {'_id': ObjectId('573a1393f29313caabcdc50e'), 'title': 'The Land'},
#  {'_id': ObjectId('573a1393f29313caabcdc514'), 'title': 'The Little Foxes'},
#  {'_id': ObjectId('573a1393f29313caabcdc530'), 'title': 'The Lady Eve'},
#  {'_id': ObjectId('573a1393f29313caabcdc536'), 'title': 'The Maltese Falcon'},
#  {'_id': ObjectId('573a1393f29313caabcdc558'),
#   'title': 'The Man Who Came to Dinner'},
#  {'_id': ObjectId('573a1393f29313caabcdc5cb'), 'title': 'Penny Serenade'},
#  {'_id': ObjectId('573a1393f29313caabcdc62b'), 'title': 'Road to Zanzibar'},
#  {'_id': ObjectId('573a1393f29313caabcdc664'), 'title': 'The Sea Wolf'},
#  {'_id': ObjectId('573a1393f29313caabcdc672'), 'title': 'Sergeant York'},
#  {'_id': ObjectId('573a1393f29313caabcdc6ae'), 'title': "Sullivan's Travels"},
#  {'_id': ObjectId('573a1393f29313caabcdc6b8'), 'title': 'Suspicion'},
#  {'_id': ObjectId('573a1393f29313caabcdc6e9'), 'title': 'Tom Dick and Harry'},
#  {'_id': ObjectId('573a1393f29313caabcdc706'), 'title': 'Two-Faced Woman'},
#  {'_id': ObjectId('573a1393f29313caabcdc742'), 'title': 'The Wolf Man'},
#  {'_id': ObjectId('573a1393f29313caabcdc77e'), 'title': 'Across the Pacific'},
#  {'_id': ObjectId('573a1393f29313caabcdc7aa'), 'title': 'Bambi'},
#  {'_id': ObjectId('573a1393f29313caabcdc7c9'), 'title': 'The Black Swan'},
#  {'_id': ObjectId('573a1393f29313caabcdc810'), 'title': 'Casablanca'},
#  {'_id': ObjectId('573a1393f29313caabcdc814'), 'title': 'Cat People'},
#  {'_id': ObjectId('573a1393f29313caabcdc87b'), 'title': 'People on the Alps'},
#  {'_id': ObjectId('573a1393f29313caabcdc8f0'), 'title': 'The Hard Way'},
#  {'_id': ObjectId('573a1393f29313caabcdc91c'), 'title': 'Holiday Inn'},
#  {'_id': ObjectId('573a1393f29313caabcdc953'), 'title': 'Jungle Book'},
#  {'_id': ObjectId('573a1393f29313caabcdc958'),
#   'title': 'Journey for Margaret'},
#  {'_id': ObjectId('573a1393f29313caabcdc9ab'),
#   'title': 'The Magnificent Ambersons'},
#  {'_id': ObjectId('573a1393f29313caabcdc9ba'), 'title': 'The Male Animal'},
#  {'_id': ObjectId('573a1393f29313caabcdc9ce'),
#   'title': 'The Major and the Minor'},
#  {'_id': ObjectId('573a1393f29313caabcdc9f5'),
#   'title': 'The Moon and Sixpence'},
#  {'_id': ObjectId('573a1393f29313caabcdca03'), 'title': 'Mrs. Miniver'},
#  {'_id': ObjectId('573a1393f29313caabcdca0c'), 'title': 'Native Land'},
#  {'_id': ObjectId('573a1393f29313caabcdca18'), 'title': 'My Gal Sal'},
#  {'_id': ObjectId('573a1393f29313caabcdca27'), 'title': 'Now, Voyager'},
#  {'_id': ObjectId('573a1393f29313caabcdca58'), 'title': 'The Pied Piper'},
#  {'_id': ObjectId('573a1393f29313caabcdca76'), 'title': 'Prelude to War'},
#  {'_id': ObjectId('573a1393f29313caabcdca79'),
#   'title': 'The Pride of the Yankees'},
#  {'_id': ObjectId('573a1393f29313caabcdca8a'), 'title': 'Random Harvest'},
#  {'_id': ObjectId('573a1393f29313caabcdca90'), 'title': 'Reap the Wild Wind'},
#  {'_id': ObjectId('573a1393f29313caabcdcaa1'), 'title': 'Road to Morocco'},
#  {'_id': ObjectId('573a1393f29313caabcdcab3'), 'title': 'Saboteur'},
#  {'_id': ObjectId('573a1393f29313caabcdcb42'), 'title': 'Kate & Leopold'},
#  {'_id': ObjectId('573a1393f29313caabcdcb60'), 'title': 'This Above All'},
#  {'_id': ObjectId('573a1393f29313caabcdcb64'), 'title': 'To Be or Not to Be'},
#  {'_id': ObjectId('573a1393f29313caabcdcbc9'), 'title': 'Wake Island'},
#  {'_id': ObjectId('573a1393f29313caabcdcbdd'), 'title': 'Woman of the Year'},
#  {'_id': ObjectId('573a1393f29313caabcdcbfb'), 'title': 'Yankee Doodle Dandy'},
#  {'_id': ObjectId('573a1393f29313caabcdcc03'), 'title': 'Air Force'},
#  {'_id': ObjectId('573a1393f29313caabcdcc33'), 'title': 'Bataan'},
#  {'_id': ObjectId('573a1393f29313caabcdcc5c'), 'title': 'Cabin in the Sky'},
#  {'_id': ObjectId('573a1393f29313caabcdcd1a'),
#   'title': 'For Whom the Bell Tolls'},
#  {'_id': ObjectId('573a1393f29313caabcdcd39'), 'title': "The Gang's All Here"},
#  {'_id': ObjectId('573a1393f29313caabcdcd4e'), 'title': 'The Ghost Ship'},
#  {'_id': ObjectId('573a1393f29313caabcdcd6b'), 'title': 'Hangmen Also Die!'},
#  {'_id': ObjectId('573a1393f29313caabcdcd7b'), 'title': 'Hello Frisco, Hello'},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'title': 'I Walked with a Zombie'},
#  {'_id': ObjectId('573a1393f29313caabcdcda1'), 'title': 'Holy Matrimony'},
#  {'_id': ObjectId('573a1393f29313caabcdcda3'), 'title': 'The Human Comedy'},
#  {'_id': ObjectId('573a1393f29313caabcdcde5'), 'title': 'Lassie Come Home'},
#  {'_id': ObjectId('573a1393f29313caabcdcdf5'), 'title': 'The Leopard Man'},
#  {'_id': ObjectId('573a1393f29313caabcdce1b'),
#   'title': 'Meshes of the Afternoon'},
#  {'_id': ObjectId('573a1393f29313caabcdce23'),
#   'title': 'The Memphis Belle: A Story of a Flying Fortress'},
#  {'_id': ObjectId('573a1393f29313caabcdce39'),
#   'title': 'The More the Merrier'},
#  {'_id': ObjectId('573a1393f29313caabcdce75'), 'title': 'The Ox-Bow Incident'},
#  {'_id': ObjectId('573a1393f29313caabcdce88'),
#   'title': 'Phantom of the Opera'},
#  {'_id': ObjectId('573a1393f29313caabcdceb0'),
#   'title': 'Report from the Aleutians'},
#  {'_id': ObjectId('573a1393f29313caabcdced3'), 'title': 'Saludos Amigos'},
#  {'_id': ObjectId('573a1393f29313caabcdceee'), 'title': 'The Seventh Victim'},
#  {'_id': ObjectId('573a1393f29313caabcdcef2'), 'title': 'Shadow of a Doubt'},
#  {'_id': ObjectId('573a1393f29313caabcdcef3'), 'title': 'So Proudly We Hail!'},
#  {'_id': ObjectId('573a1393f29313caabcdcf0e'),
#   'title': 'The Song of Bernadette'},
#  {'_id': ObjectId('573a1393f29313caabcdcf14'), 'title': 'Stormy Weather'},
#  {'_id': ObjectId('573a1393f29313caabcdcf2f'), 'title': 'This Is the Army'},
#  {'_id': ObjectId('573a1393f29313caabcdcf71'),
#   'title': 'Victory Through Air Power'},
#  {'_id': ObjectId('573a1393f29313caabcdcf84'), 'title': 'Watch on the Rhine'},
#  {'_id': ObjectId('573a1393f29313caabcdcff5'),
#   'title': 'The Battle of Russia'},
#  {'_id': ObjectId('573a1393f29313caabcdcffa'), 'title': 'San Pietro'},
#  {'_id': ObjectId('573a1393f29313caabcdd009'),
#   'title': 'Arsenic and Old Lace'},
#  {'_id': ObjectId('573a1393f29313caabcdd05c'), 'title': 'Cover Girl'},
#  {'_id': ObjectId('573a1393f29313caabcdd05d'),
#   'title': 'The Curse of the Cat People'},
#  {'_id': ObjectId('573a1393f29313caabcdd0ae'), 'title': 'Double Indemnity'},
#  {'_id': ObjectId('573a1393f29313caabcdd0b6'), 'title': 'The Fighting Lady'},
#  {'_id': ObjectId('573a1393f29313caabcdd0e5'),
#   'title': 'The Best Years of Our Lives'},
#  {'_id': ObjectId('573a1393f29313caabcdd0eb'), 'title': 'Gaslight'},
#  {'_id': ObjectId('573a1393f29313caabcdd0f1'), 'title': 'Going My Way'},
#  {'_id': ObjectId('573a1393f29313caabcdd0fa'),
#   'title': 'Hail the Conquering Hero'},
#  {'_id': ObjectId('573a1393f29313caabcdd170'), 'title': 'Laura'},
#  {'_id': ObjectId('573a1393f29313caabcdd179'), 'title': 'Lifeboat'},
#  {'_id': ObjectId('573a1393f29313caabcdd1a3'),
#   'title': 'Meet Me in St. Louis'},
#  {'_id': ObjectId('573a1393f29313caabcdd1bf'),
#   'title': "The Miracle of Morgan's Creek"},
#  {'_id': ObjectId('573a1393f29313caabcdd1d2'), 'title': 'Mrs. Parkington'},
#  {'_id': ObjectId('573a1393f29313caabcdd1ec'), 'title': 'Murder, My Sweet'},
#  {'_id': ObjectId('573a1393f29313caabcdd1f1'),
#   'title': 'None But the Lonely Heart'},
#  {'_id': ObjectId('573a1393f29313caabcdd1f5'), 'title': 'National Velvet'},
#  {'_id': ObjectId('573a1393f29313caabcdd2a7'), 'title': 'Since You Went Away'},
#  {'_id': ObjectId('573a1393f29313caabcdd2eb'),
#   'title': 'Thirty Seconds Over Tokyo'},
#  {'_id': ObjectId('573a1393f29313caabcdd31c'), 'title': 'Tunisian Victory'},
#  {'_id': ObjectId('573a1393f29313caabcdd342'), 'title': 'Wilson'},
#  {'_id': ObjectId('573a1393f29313caabcdd36a'), 'title': 'Anchors Aweigh'},
#  {'_id': ObjectId('573a1393f29313caabcdd374'),
#   'title': 'And Then There Were None'},
#  {'_id': ObjectId('573a1393f29313caabcdd38a'),
#   'title': "The Bells of St. Mary's"},
#  {'_id': ObjectId('573a1393f29313caabcdd38c'), 'title': 'The Body Snatcher'},
#  {'_id': ObjectId('573a1393f29313caabcdd3ce'), 'title': 'The Clock'},
#  {'_id': ObjectId('573a1393f29313caabcdd3e5'), 'title': 'Detour'},
#  {'_id': ObjectId('573a1393f29313caabcdd40f'), 'title': "L'espoir"},
#  {'_id': ObjectId('573a1393f29313caabcdd414'),
#   'title': 'Children of Paradise'},
#  {'_id': ObjectId('573a1393f29313caabcdd481'), 'title': 'House of Dracula'},
#  {'_id': ObjectId('573a1393f29313caabcdd482'),
#   'title': 'The House on 92nd Street'},
#  {'_id': ObjectId('573a1393f29313caabcdd49b'), 'title': 'Isle of the Dead'},
#  {'_id': ObjectId('573a1393f29313caabcdd4c8'), 'title': 'Leave Her to Heaven'},
#  {'_id': ObjectId('573a1393f29313caabcdd4dc'), 'title': 'The Lost Weekend'},
#  {'_id': ObjectId('573a1393f29313caabcdd4f9'), 'title': 'Mildred Pierce'},
#  {'_id': ObjectId('573a1393f29313caabcdd544'),
#   'title': 'The Picture of Dorian Gray'},
#  {'_id': ObjectId('573a1393f29313caabcdd551'), 'title': 'La perla'},
#  {'_id': ObjectId('573a1393f29313caabcdd574'), 'title': 'Rhapsody in Blue'},
#  {'_id': ObjectId('573a1393f29313caabcdd5ba'), 'title': 'The Southerner'},
#  {'_id': ObjectId('573a1393f29313caabcdd5bc'), 'title': 'Spellbound'},
#  {'_id': ObjectId('573a1393f29313caabcdd5c7'), 'title': 'Story of G.I. Joe'},
#  {'_id': ObjectId('573a1393f29313caabcdd5cc'), 'title': 'A Song to Remember'},
#  {'_id': ObjectId('573a1393f29313caabcdd5cd'), 'title': 'State Fair'},
#  {'_id': ObjectId('573a1393f29313caabcdd60a'),
#   'title': 'The Three Caballeros'},
#  {'_id': ObjectId('573a1393f29313caabcdd622'),
#   'title': 'A Tree Grows in Brooklyn'},
#  {'_id': ObjectId('573a1393f29313caabcdd62e'),
#   'title': 'The Valley of Decision'},
#  {'_id': ObjectId('573a1393f29313caabcdd652'), 'title': 'Wonder Man'},
#  {'_id': ObjectId('573a1393f29313caabcdd659'), 'title': 'A Walk in the Sun'},
#  {'_id': ObjectId('573a1393f29313caabcdd688'),
#   'title': 'Anna and the King of Siam'},
#  {'_id': ObjectId('573a1393f29313caabcdd69c'),
#   'title': 'The Battle of the Rails'},
#  {'_id': ObjectId('573a1393f29313caabcdd6aa'),
#   'title': 'Beauty and the Beast'},
#  {'_id': ObjectId('573a1393f29313caabcdd6b0'), 'title': 'Bedlam'},
#  {'_id': ObjectId('573a1393f29313caabcdd6b2'), 'title': 'The Big Sleep'},
#  {'_id': ObjectId('573a1393f29313caabcdd6b8'),
#   'title': 'The Best Years of Our Lives'},
#  {'_id': ObjectId('573a1393f29313caabcdd6e7'), 'title': 'The Chase'},
#  {'_id': ObjectId('573a1393f29313caabcdd72b'), 'title': 'Devil in the Flesh'},
#  {'_id': ObjectId('573a1393f29313caabcdd72d'),
#   'title': 'The Diary of a Chambermaid'},
#  {'_id': ObjectId('573a1393f29313caabcdd758'), 'title': 'Duel in the Sun'},
#  {'_id': ObjectId('573a1393f29313caabcdd788'), 'title': 'Gilda'},
#  {'_id': ObjectId('573a1393f29313caabcdd79b'), 'title': 'The Harvey Girls'},
#  {'_id': ObjectId('573a1393f29313caabcdd7d8'),
#   'title': "It's a Wonderful Life"},
#  {'_id': ObjectId('573a1393f29313caabcdd7ed'), 'title': 'The Jolson Story'},
#  {'_id': ObjectId('573a1393f29313caabcdd800'), 'title': 'The Killers'},
#  {'_id': ObjectId('573a1393f29313caabcdd807'), 'title': 'Let There Be Light'},
#  {'_id': ObjectId('573a1393f29313caabcdd831'), 'title': 'Make Mine Music'},
#  {'_id': ObjectId('573a1393f29313caabcdd852'),
#   'title': 'My Darling Clementine'},
#  {'_id': ObjectId('573a1393f29313caabcdd86b'), 'title': 'Notorious'},
#  {'_id': ObjectId('573a1393f29313caabcdd89b'), 'title': 'Panic'},
#  {'_id': ObjectId('573a1393f29313caabcdd8b6'), 'title': "The Razor's Edge"},
#  {'_id': ObjectId('573a1393f29313caabcdd901'), 'title': 'Sister Kenny'},
#  {'_id': ObjectId('573a1393f29313caabcdd916'), 'title': 'Song of the South'},
#  {'_id': ObjectId('573a1393f29313caabcdd934'),
#   'title': 'The Strange Love of Martha Ivers'},
#  {'_id': ObjectId('573a1393f29313caabcdd937'), 'title': 'The Stranger'},
#  {'_id': ObjectId('573a1393f29313caabcdd943'), 'title': 'Pastoral Symphony'},
#  {'_id': ObjectId('573a1393f29313caabcdd95d'), 'title': 'To Each His Own'},
#  {'_id': ObjectId('573a1393f29313caabcdd9af'), 'title': 'The Yearling'},
#  {'_id': ObjectId('573a1393f29313caabcdd9b4'), 'title': 'Ziegfeld Follies'},
#  {'_id': ObjectId('573a1393f29313caabcdd9c7'),
#   'title': 'The Eagle with Two Heads'},
#  {'_id': ObjectId('573a1393f29313caabcdd9fe'), 'title': "The Bishop's Wife"},
#  {'_id': ObjectId('573a1393f29313caabcdda01'), 'title': 'Body and Soul'},
#  {'_id': ObjectId('573a1393f29313caabcdda05'), 'title': 'Boomerang!'},
#  {'_id': ObjectId('573a1393f29313caabcdda18'), 'title': 'Bowery Buckaroos'},
#  {'_id': ObjectId('573a1393f29313caabcdda52'), 'title': 'The Cat Concerto'},
#  {'_id': ObjectId('573a1393f29313caabcdda5e'), 'title': 'Crossfire'},
#  {'_id': ObjectId('573a1393f29313caabcdda94'),
#   'title': 'Dreams That Money Can Buy'},
#  {'_id': ObjectId('573a1393f29313caabcdda98'), 'title': "Dèdèe d'Anvers"},
#  {'_id': ObjectId('573a1393f29313caabcdda9a'), 'title': 'A Double Life'},
#  {'_id': ObjectId('573a1393f29313caabcddab2'),
#   'title': "The Farmer's Daughter"},
#  {'_id': ObjectId('573a1393f29313caabcddad5'),
#   'title': "Gentleman's Agreement"},
#  {'_id': ObjectId('573a1393f29313caabcddae1'), 'title': 'Germany Year Zero'},
#  {'_id': ObjectId('573a1393f29313caabcddaf1'), 'title': 'The Fugitive'},
#  {'_id': ObjectId('573a1393f29313caabcddaf5'),
#   'title': 'Green Dolphin Street'},
#  {'_id': ObjectId('573a1393f29313caabcddb2b'),
#   'title': 'It Happened on Fifth Avenue'},
#  {'_id': ObjectId('573a1393f29313caabcddb58'), 'title': 'Kiss of Death'},
#  {'_id': ObjectId('573a1393f29313caabcddb6c'), 'title': 'Life with Father'},
#  {'_id': ObjectId('573a1393f29313caabcddba7'), 'title': 'The Damned'},
#  {'_id': ObjectId('573a1393f29313caabcddbb0'), 'title': 'Mother Wore Tights'},
#  {'_id': ObjectId('573a1393f29313caabcddbb5'),
#   'title': 'Miracle on 34th Street'},
#  {'_id': ObjectId('573a1393f29313caabcddbb7'), 'title': 'Monsieur Verdoux'},
#  {'_id': ObjectId('573a1393f29313caabcddbb8'), 'title': 'Monsieur Vincent'},
#  {'_id': ObjectId('573a1393f29313caabcddbbc'),
#   'title': 'Mourning Becomes Electra'},
#  {'_id': ObjectId('573a1393f29313caabcddbe6'), 'title': 'Out of the Past'},
#  {'_id': ObjectId('573a1393f29313caabcddc0a'), 'title': 'Possessed'},
#  {'_id': ObjectId('573a1393f29313caabcddc2a'), 'title': 'The Red House'},
#  {'_id': ObjectId('573a1393f29313caabcddc39'), 'title': 'Quai des Orfèvres'},
#  {'_id': ObjectId('573a1393f29313caabcddc55'),
#   'title': 'The Adventures of Robin Hood'},
#  {'_id': ObjectId('573a1393f29313caabcddc78'),
#   'title': 'The Sin of Harold Diddlebock'},
#  {'_id': ObjectId('573a1393f29313caabcddd6a'),
#   'title': 'Adventures of Don Juan'},
#  {'_id': ObjectId('573a1393f29313caabcddd6d'), 'title': 'An Act of Murder'},
#  {'_id': ObjectId('573a1393f29313caabcddd7d'), 'title': 'All My Sons'},
#  {'_id': ObjectId('573a1393f29313caabcddd85'),
#   'title': 'Bud Abbott Lou Costello Meet Frankenstein'},
#  {'_id': ObjectId('573a1393f29313caabcddd8a'), 'title': "Angels' Alley"},
#  {'_id': ObjectId('573a1393f29313caabcddd8f'), 'title': 'Apartment for Peggy'},
#  {'_id': ObjectId('573a1393f29313caabcdddb8'), 'title': 'Berlin Express'},
#  {'_id': ObjectId('573a1393f29313caabcdddc7'),
#   'title': 'The Walls of Malapaga'},
#  {'_id': ObjectId('573a1393f29313caabcdddc8'), 'title': 'The Big Clock'},
#  {'_id': ObjectId('573a1393f29313caabcddde7'), 'title': 'Call Northside 777'},
#  {'_id': ObjectId('573a1393f29313caabcdde0f'), 'title': 'Command Decision'},
#  {'_id': ObjectId('573a1393f29313caabcdde29'), 'title': 'Cry of the City'},
#  {'_id': ObjectId('573a1393f29313caabcdde51'), 'title': 'Easter Parade'},
#  {'_id': ObjectId('573a1393f29313caabcdde5a'), 'title': 'The Emperor Waltz'},
#  {'_id': ObjectId('573a1393f29313caabcdde7c'),
#   'title': 'Every Girl Should Be Married'},
#  {'_id': ObjectId('573a1393f29313caabcdde8b'), 'title': 'Force of Evil'},
#  {'_id': ObjectId('573a1393f29313caabcdde97'), 'title': 'A Foreign Affair'},
#  {'_id': ObjectId('573a1393f29313caabcddea3'), 'title': 'Fort Apache'},
#  {'_id': ObjectId('573a1393f29313caabcdded2'), 'title': 'He Walked by Night'},
#  {'_id': ObjectId('573a1393f29313caabcddef2'), 'title': 'I Remember Mama'},
#  {'_id': ObjectId('573a1393f29313caabcddf0c'), 'title': 'Johnny Belinda'},
#  {'_id': ObjectId('573a1393f29313caabcddf0e'), 'title': 'Jour de Fete'},
#  {'_id': ObjectId('573a1393f29313caabcddf1b'), 'title': 'June Bride'},
#  {'_id': ObjectId('573a1393f29313caabcddf1e'), 'title': 'Joan of Arc'},
#  {'_id': ObjectId('573a1393f29313caabcddf23'), 'title': 'Key Largo'},
#  {'_id': ObjectId('573a1393f29313caabcddf35'),
#   'title': 'Letter from an Unknown Woman'},
#  {'_id': ObjectId('573a1393f29313caabcddf4d'), 'title': 'Louisiana Story'},
#  {'_id': ObjectId('573a1393f29313caabcddf56'), 'title': 'Macbeth'},
#  {'_id': ObjectId('573a1393f29313caabcddf5e'),
#   'title': 'The Mating of Millie'},
#  {'_id': ObjectId('573a1393f29313caabcddf76'), 'title': 'Melody Time'},
#  {'_id': ObjectId('573a1393f29313caabcddf82'),
#   'title': 'Mr. Blandings Builds His Dream House'},
#  {'_id': ObjectId('573a1393f29313caabcddfa4'), 'title': 'The Naked City'},
#  {'_id': ObjectId('573a1393f29313caabcddfcf'), 'title': 'The Paleface'},
#  {'_id': ObjectId('573a1393f29313caabcddfd3'), 'title': 'The Pirate'},
#  {'_id': ObjectId('573a1393f29313caabcddfee'),
#   'title': 'Rachel and the Stranger'},
#  {'_id': ObjectId('573a1393f29313caabcddff1'), 'title': 'Red River'},
#  {'_id': ObjectId('573a1393f29313caabcddff4'), 'title': 'Portrait of Jennie'},
#  {'_id': ObjectId('573a1393f29313caabcde008'), 'title': 'Rope'},
#  {'_id': ObjectId('573a1393f29313caabcde00c'), 'title': 'Road House'},
#  {'_id': ObjectId('573a1393f29313caabcde024'), 'title': 'The Search'},
#  {'_id': ObjectId('573a1393f29313caabcde043'), 'title': 'Sitting Pretty'},
#  {'_id': ObjectId('573a1393f29313caabcde04e'), 'title': 'The Snake Pit'},
#  {'_id': ObjectId('573a1393f29313caabcde05f'), 'title': 'Sorry, Wrong Number'},
#  {'_id': ObjectId('573a1393f29313caabcde061'), 'title': 'Station West'},
#  {'_id': ObjectId('573a1393f29313caabcde07e'),
#   'title': 'The Street with No Name'},
#  {'_id': ObjectId('573a1393f29313caabcde083'), 'title': 'That Lady in Ermine'},
#  {'_id': ObjectId('573a1393f29313caabcde09f'),
# ...
#  {'_id': ObjectId('573a1394f29313caabcdf379'), 'title': "Eaux d'artifice"},
#  {'_id': ObjectId('573a1394f29313caabcdf39e'), 'title': 'Fear and Desire'},
#  {'_id': ObjectId('573a1394f29313caabcdf3af'),
#   'title': 'From Here to Eternity'},
#  {'_id': ObjectId('573a1394f29313caabcdf3ce'), 'title': 'The Glass Wall'},
#  {'_id': ObjectId('573a1394f29313caabcdf3d4'),
#   'title': 'Gentlemen Prefer Blondes'},
#  {'_id': ObjectId('573a1394f29313caabcdf40d'), 'title': 'House of Wax'},
#  {'_id': ObjectId('573a1394f29313caabcdf40e'), 'title': 'The Hitch-Hiker'},
#  {'_id': ObjectId('573a1394f29313caabcdf41c'),
#   'title': 'How to Marry a Millionaire'},
#  {'_id': ObjectId('573a1394f29313caabcdf420'), 'title': 'I Confess'},
#  {'_id': ObjectId('573a1394f29313caabcdf42f'),
#   'title': 'It Came from Outer Space'},
#  {'_id': ObjectId('573a1394f29313caabcdf43f'), 'title': 'Invaders from Mars'},
#  {'_id': ObjectId('573a1394f29313caabcdf446'), 'title': 'Julius Caesar'},
#  {'_id': ObjectId('573a1394f29313caabcdf461'), 'title': 'Kiss Me Kate'},
#  {'_id': ObjectId('573a1394f29313caabcdf465'),
#   'title': 'Knights of the Round Table'},
#  {'_id': ObjectId('573a1394f29313caabcdf47d'), 'title': 'Lili'},
#  {'_id': ObjectId('573a1394f29313caabcdf481'), 'title': 'Little Boy Lost'},
#  {'_id': ObjectId('573a1394f29313caabcdf485'), 'title': 'The Living Desert'},
#  {'_id': ObjectId('573a1394f29313caabcdf488'), 'title': 'Loose in London'},
#  {'_id': ObjectId('573a1394f29313caabcdf48b'), 'title': 'Little Fugitive'},
#  {'_id': ObjectId('573a1394f29313caabcdf4b7'), 'title': 'Man on a Tightrope'},
#  {'_id': ObjectId('573a1394f29313caabcdf4dc'), 'title': 'Mogambo'},
#  {'_id': ObjectId('573a1394f29313caabcdf4e4'), 'title': 'The Moon Is Blue'},
#  {'_id': ObjectId('573a1394f29313caabcdf513'),
#   'title': 'The Proud and the Beautiful'},
#  {'_id': ObjectId('573a1394f29313caabcdf534'), 'title': 'Peter Pan'},
#  {'_id': ObjectId('573a1394f29313caabcdf539'),
#   'title': 'Pickup on South Street'},
#  {'_id': ObjectId('573a1394f29313caabcdf57d'), 'title': 'The Robe'},
#  {'_id': ObjectId('573a1394f29313caabcdf57e'), 'title': 'Roman Holiday'},
#  {'_id': ObjectId('573a1394f29313caabcdf58a'), 'title': 'The Wages of Fear'},
#  {'_id': ObjectId('573a1394f29313caabcdf5aa'), 'title': 'Shane'},
#  {'_id': ObjectId('573a1394f29313caabcdf5b5'),
#   'title': 'The Lady Without Camelias'},
#  {'_id': ObjectId('573a1394f29313caabcdf5e7'), 'title': 'Statues also Die'},
#  {'_id': ObjectId('573a1394f29313caabcdf5ec'), 'title': 'Stalag 17'},
#  {'_id': ObjectId('573a1394f29313caabcdf5f3'),
#   'title': 'Indiscretion of an American Wife'},
#  {'_id': ObjectId('573a1394f29313caabcdf5fb'),
#   'title': 'The Story of Three Loves'},
#  {'_id': ObjectId('573a1394f29313caabcdf61c'),
#   'title': 'The Sun Shines Bright'},
#  {'_id': ObjectId('573a1394f29313caabcdf624'), 'title': 'Beat the Devil'},
#  {'_id': ObjectId('573a1394f29313caabcdf633'), 'title': 'The Adultress'},
#  {'_id': ObjectId('573a1394f29313caabcdf639'), 'title': 'Titanic'},
#  {'_id': ObjectId('573a1394f29313caabcdf63f'),
#   'title': 'Touchez Pas au Grisbi'},
#  {'_id': ObjectId('573a1394f29313caabcdf64b'), 'title': 'Torch Song'},
#  {'_id': ObjectId('573a1394f29313caabcdf663'), 'title': "Mr. Hulot's Holiday"},
#  {'_id': ObjectId('573a1394f29313caabcdf67a'), 'title': 'Journey to Italy'},
#  {'_id': ObjectId('573a1394f29313caabcdf691'),
#   'title': 'The War of the Worlds'},
#  {'_id': ObjectId('573a1394f29313caabcdf699'), 'title': 'I Vitelloni'},
#  {'_id': ObjectId('573a1394f29313caabcdf6ce'), 'title': 'Young Bess'},
#  {'_id': ObjectId('573a1394f29313caabcdf725'),
#   'title': '20,000 Leagues Under the Sea'},
#  {'_id': ObjectId('573a1394f29313caabcdf779'), 'title': 'Beat the Devil'},
#  {'_id': ObjectId('573a1394f29313caabcdf77f'),
#   'title': 'The Barefoot Contessa'},
#  {'_id': ObjectId('573a1394f29313caabcdf7a1'), 'title': 'Brigadoon'},
#  {'_id': ObjectId('573a1394f29313caabcdf7a9'),
#   'title': 'The Bridges at Toko-Ri'},
#  {'_id': ObjectId('573a1394f29313caabcdf7b6'), 'title': 'Broken Lance'},
#  {'_id': ObjectId('573a1394f29313caabcdf7bf'), 'title': 'The Caine Mutiny'},
#  {'_id': ObjectId('573a1394f29313caabcdf7d5'), 'title': 'Carmen Jones'},
#  {'_id': ObjectId('573a1394f29313caabcdf7da'),
#   'title': 'The Count of Monte Cristo'},
#  {'_id': ObjectId('573a1394f29313caabcdf7e2'), 'title': 'The Country Girl'},
#  {'_id': ObjectId('573a1394f29313caabcdf7e3'),
#   'title': 'Creature from the Black Lagoon'},
#  {'_id': ObjectId('573a1394f29313caabcdf807'), 'title': 'Diabolique'},
#  {'_id': ObjectId('573a1394f29313caabcdf81b'), 'title': 'Dial M for Murder'},
#  {'_id': ObjectId('573a1394f29313caabcdf82d'), 'title': 'The Egyptian'},
#  {'_id': ObjectId('573a1394f29313caabcdf845'), 'title': 'Executive Suite'},
#  {'_id': ObjectId('573a1394f29313caabcdf888'),
#   'title': 'The Glenn Miller Story'},
#  {'_id': ObjectId('573a1394f29313caabcdf8a9'), 'title': 'Hell and High Water'},
#  {'_id': ObjectId('573a1394f29313caabcdf8b5'),
#   'title': 'The High and the Mighty'},
#  {'_id': ObjectId('573a1394f29313caabcdf8db'),
#   'title': 'It Should Happen to You'},
#  {'_id': ObjectId('573a1394f29313caabcdf8e7'), 'title': 'Johnny Guitar'},
#  {'_id': ObjectId('573a1394f29313caabcdf902'), 'title': 'Knock on Wood'},
#  {'_id': ObjectId('573a1394f29313caabcdf913'), 'title': 'Liliomfi'},
#  {'_id': ObjectId('573a1394f29313caabcdf91f'),
#   'title': 'The Long, Long Trailer'},
#  {'_id': ObjectId('573a1394f29313caabcdf953'),
#   'title': 'Lovers, Happy Lovers!'},
#  {'_id': ObjectId('573a1394f29313caabcdf956'),
#   'title': 'Magnificent Obsession'},
#  {'_id': ObjectId('573a1394f29313caabcdf96d'),
#   'title': 'The Sheep Has Five Legs'},
#  {'_id': ObjectId('573a1394f29313caabcdf987'), 'title': 'On the Waterfront'},
#  {'_id': ObjectId('573a1394f29313caabcdf9c7'), 'title': 'Phffft'},
#  {'_id': ObjectId('573a1394f29313caabcdfa00'), 'title': 'Rear Window'},
#  {'_id': ObjectId('573a1394f29313caabcdfa02'),
#   'title': 'Riot in Cell Block 11'},
#  {'_id': ObjectId('573a1394f29313caabcdfa1a'), 'title': 'Rouge et noir'},
#  {'_id': ObjectId('573a1394f29313caabcdfa1f'), 'title': 'Sabrina'},
#  {'_id': ObjectId('573a1394f29313caabcdfa25'), 'title': 'Salt of the Earth'},
#  {'_id': ObjectId('573a1394f29313caabcdfa38'),
#   'title': 'Seven Brides for Seven Brothers'},
#  {'_id': ObjectId('573a1394f29313caabcdfa75'), 'title': 'A Star Is Born'},
#  {'_id': ObjectId('573a1394f29313caabcdfa86'), 'title': 'Susan Slept Here'},
#  {'_id': ObjectId('573a1394f29313caabcdfa9c'), 'title': 'Them!'},
#  {'_id': ObjectId('573a1394f29313caabcdfa9d'),
#   'title': "There's No Business Like Show Business"},
#  {'_id': ObjectId('573a1394f29313caabcdfaaa'), 'title': 'This Island Earth'},
#  {'_id': ObjectId('573a1394f29313caabcdfaad'),
#   'title': 'Three Coins in the Fountain'},
#  {'_id': ObjectId('573a1394f29313caabcdfaf6'),
#   'title': 'The Vanishing Prairie'},
#  {'_id': ObjectId('573a1394f29313caabcdfb88'),
#   'title': 'All That Heaven Allows'},
#  {'_id': ObjectId('573a1394f29313caabcdfbb7'),
#   'title': 'Bad Day at Black Rock'},
#  {'_id': ObjectId('573a1394f29313caabcdfbd0'), 'title': 'Blackboard Jungle'},
#  {'_id': ObjectId('573a1394f29313caabcdfbe0'), 'title': 'The Big Knife'},
#  {'_id': ObjectId('573a1394f29313caabcdfbe6'), 'title': 'Blinkity Blank'},
#  {'_id': ObjectId('573a1394f29313caabcdfbf1'), 'title': 'Il Bidone'},
#  {'_id': ObjectId('573a1394f29313caabcdfc17'),
#   'title': 'The Court-Martial of Billy Mitchell'},
#  {'_id': ObjectId('573a1394f29313caabcdfc23'), 'title': 'Daddy Long Legs'},
#  {'_id': ObjectId('573a1394f29313caabcdfc33'), 'title': 'The Desperate Hours'},
#  {'_id': ObjectId('573a1394f29313caabcdfc58'), 'title': 'Rififi'},
#  {'_id': ObjectId('573a1394f29313caabcdfc68'), 'title': 'East of Eden'},
#  {'_id': ObjectId('573a1394f29313caabcdfcc6'), 'title': 'The Grand Maneuver'},
#  {'_id': ObjectId('573a1394f29313caabcdfcd0'), 'title': 'The Grand Maneuver'},
#  {'_id': ObjectId('573a1394f29313caabcdfcd7'), 'title': 'Guys and Dolls'},
#  {'_id': ObjectId('573a1394f29313caabcdfd0a'), 'title': "I'll Cry Tomorrow"},
#  {'_id': ObjectId('573a1394f29313caabcdfd10'), 'title': 'Wild Love'},
#  {'_id': ObjectId('573a1394f29313caabcdfd19'),
#   'title': "It's Always Fair Weather"},
#  {'_id': ObjectId('573a1394f29313caabcdfd1e'), 'title': 'Interrupted Melody'},
#  {'_id': ObjectId('573a1394f29313caabcdfd45'), 'title': 'Kiss Me Deadly'},
#  {'_id': ObjectId('573a1394f29313caabcdfd48'), 'title': "Killer's Kiss"},
#  {'_id': ObjectId('573a1394f29313caabcdfd4c'), 'title': 'The Kentuckian'},
#  {'_id': ObjectId('573a1394f29313caabcdfd61'), 'title': 'Lady and the Tramp'},
#  {'_id': ObjectId('573a1394f29313caabcdfd7b'),
#   'title': 'Love Is a Many-Splendored Thing'},
#  {'_id': ObjectId('573a1394f29313caabcdfd8b'), 'title': 'The Long Gray Line'},
#  {'_id': ObjectId('573a1394f29313caabcdfd8f'), 'title': 'A Man Called Peter'},
#  {'_id': ObjectId('573a1394f29313caabcdfd90'), 'title': 'Love Me or Leave Me'},
#  {'_id': ObjectId('573a1394f29313caabcdfd99'),
#   'title': 'The Man with the Golden Arm'},
#  {'_id': ObjectId('573a1394f29313caabcdfda2'), 'title': 'Marty'},
#  {'_id': ObjectId('573a1394f29313caabcdfdcd'), 'title': 'Mister Roberts'},
#  {'_id': ObjectId('573a1394f29313caabcdfdee'), 'title': 'Night and Fog'},
#  {'_id': ObjectId('573a1394f29313caabcdfdf9'), 'title': 'Oklahoma!'},
#  {'_id': ObjectId('573a1394f29313caabcdfdfb'),
#   'title': 'The Night of the Hunter'},
#  {'_id': ObjectId('573a1394f29313caabcdfe01'), 'title': 'Not as a Stranger'},
#  {'_id': ObjectId('573a1394f29313caabcdfe09'), 'title': 'One Froggy Evening'},
#  {'_id': ObjectId('573a1394f29313caabcdfe26'), 'title': 'Picnic'},
#  {'_id': ObjectId('573a1394f29313caabcdfe29'), 'title': "Pete Kelly's Blues"},
#  {'_id': ObjectId('573a1394f29313caabcdfe5b'),
#   'title': 'Rebel Without a Cause'},
#  {'_id': ObjectId('573a1394f29313caabcdfe78'), 'title': 'The Rose Tattoo'},
#  {'_id': ObjectId('573a1394f29313caabcdfea1'), 'title': 'The Seven Year Itch'},
#  {'_id': ObjectId('573a1394f29313caabcdfedf'),
#   'title': 'Strategic Air Command'},
#  {'_id': ObjectId('573a1394f29313caabcdfef0'), 'title': 'Summertime'},
#  {'_id': ObjectId('573a1394f29313caabcdff06'), 'title': 'The Tender Trap'},
#  {'_id': ObjectId('573a1394f29313caabcdff1d'), 'title': 'To Catch a Thief'},
#  {'_id': ObjectId('573a1394f29313caabcdff2f'), 'title': 'Trial'},
#  {'_id': ObjectId('573a1394f29313caabcdff4c'),
#   'title': 'The Trouble with Harry'},
#  {'_id': ObjectId('573a1394f29313caabcdff62'), 'title': 'The Violent Men'},
#  {'_id': ObjectId('573a1394f29313caabcdffeb'), 'title': 'Anastasia'},
#  {'_id': ObjectId('573a1394f29313caabcdfff7'), 'title': 'Alexander the Great'},
#  {'_id': ObjectId('573a1394f29313caabcdffff'), 'title': 'Attack'},
#  {'_id': ObjectId('573a1394f29313caabce0003'),
#   'title': 'Around the World in Eighty Days'},
#  {'_id': ObjectId('573a1394f29313caabce000d'), 'title': 'The Red Balloon'},
#  {'_id': ObjectId('573a1394f29313caabce0014'), 'title': 'The Bad Seed'},
#  {'_id': ObjectId('573a1394f29313caabce0021'), 'title': 'Autumn Leaves'},
#  {'_id': ObjectId('573a1394f29313caabce0024'), 'title': 'Baby Doll'},
#  {'_id': ObjectId('573a1394f29313caabce002d'), 'title': 'Bigger Than Life'},
#  {'_id': ObjectId('573a1394f29313caabce0031'), 'title': 'Bhowani Junction'},
#  {'_id': ObjectId('573a1394f29313caabce003f'), 'title': 'The Brave One'},
#  {'_id': ObjectId('573a1394f29313caabce0046'), 'title': 'Bus Stop'},
#  {'_id': ObjectId('573a1394f29313caabce004c'), 'title': 'Main Street'},
#  {'_id': ObjectId('573a1394f29313caabce0057'), 'title': 'Carousel'},
#  {'_id': ObjectId('573a1394f29313caabce0067'), 'title': 'The Catered Affair'},
#  {'_id': ObjectId('573a1394f29313caabce0078'), 'title': 'Come Back, Africa'},
#  {'_id': ObjectId('573a1394f29313caabce008b'), 'title': 'The Court Jester'},
#  {'_id': ObjectId('573a1394f29313caabce0090'), 'title': 'Crashing Las Vegas'},
#  {'_id': ObjectId('573a1394f29313caabce00c9'),
#   'title': 'Earth vs. the Flying Saucers'},
#  {'_id': ObjectId('573a1394f29313caabce00de'),
#   'title': '...And God Created Woman'},
#  {'_id': ObjectId('573a1394f29313caabce00e0'),
#   'title': 'The Eddy Duchin Story'},
#  {'_id': ObjectId('573a1394f29313caabce0100'), 'title': 'Forbidden Planet'},
#  {'_id': ObjectId('573a1394f29313caabce0109'), 'title': 'Friendly Persuasion'},
#  {'_id': ObjectId('573a1394f29313caabce0138'),
#   'title': 'The Great Locomotive Chase'},
#  {'_id': ObjectId('573a1394f29313caabce013a'), 'title': 'Guendalina'},
#  {'_id': ObjectId('573a1394f29313caabce0142'), 'title': 'Gervaise'},
#  {'_id': ObjectId('573a1394f29313caabce0143'), 'title': 'The Great Man'},
#  {'_id': ObjectId('573a1394f29313caabce0146'), 'title': 'Giant'},
#  {'_id': ObjectId('573a1394f29313caabce0158'),
#   'title': 'The Harder They Fall'},
#  {'_id': ObjectId('573a1394f29313caabce015a'), 'title': 'High Society'},
#  {'_id': ObjectId('573a1394f29313caabce018e'),
#   'title': 'Invasion of the Body Snatchers'},
#  {'_id': ObjectId('573a1394f29313caabce01a5'),
#   'title': 'Invitation to the Dance'},
#  {'_id': ObjectId('573a1394f29313caabce01c3'), 'title': 'The King and I'},
#  {'_id': ObjectId('573a1394f29313caabce01f3'), 'title': 'Lust for Life'},
#  {'_id': ObjectId('573a1394f29313caabce01f6'),
#   'title': 'The Man Who Knew Too Much'},
#  {'_id': ObjectId('573a1394f29313caabce01f9'),
#   'title': 'The Man in the Gray Flannel Suit'},
#  {'_id': ObjectId('573a1394f29313caabce0209'),
#   'title': 'Meet Me in Las Vegas'},
#  {'_id': ObjectId('573a1394f29313caabce0230'), 'title': 'The Silent World'},
#  {'_id': ObjectId('573a1394f29313caabce0236'), 'title': 'Moby Dick'},
#  {'_id': ObjectId('573a1394f29313caabce0259'), 'title': 'An Eye for an Eye'},
#  {'_id': ObjectId('573a1394f29313caabce025e'), 'title': 'Le mystère Picasso'},
#  {'_id': ObjectId('573a1394f29313caabce02ac'), 'title': 'The Rainmaker'},
#  {'_id': ObjectId('573a1394f29313caabce0302'), 'title': 'The Searchers'},
#  {'_id': ObjectId('573a1394f29313caabce0305'), 'title': 'Secrets of Life'},
#  {'_id': ObjectId('573a1394f29313caabce031a'), 'title': 'Seven Men from Now'},
#  {'_id': ObjectId('573a1394f29313caabce0326'),
#   'title': 'The Solid Gold Cadillac'},
#  {'_id': ObjectId('573a1394f29313caabce0332'),
#   'title': 'Somebody Up There Likes Me'},
#  {'_id': ObjectId('573a1394f29313caabce035a'), 'title': 'Tea and Sympathy'},
#  {'_id': ObjectId('573a1394f29313caabce035b'),
#   'title': 'The Teahouse of the August Moon'},
#  {'_id': ObjectId('573a1394f29313caabce035e'),
#   'title': 'The Ten Commandments'},
#  {'_id': ObjectId('573a1394f29313caabce038a'), 'title': 'Four Bags Full'},
#  {'_id': ObjectId('573a1394f29313caabce0393'), 'title': 'Trapeze'},
#  {'_id': ObjectId('573a1394f29313caabce03a4'), 'title': 'A Man Escaped'},
#  {'_id': ObjectId('573a1394f29313caabce03c3'), 'title': 'War and Peace'},
#  {'_id': ObjectId('573a1394f29313caabce03e4'), 'title': 'Written on the Wind'},
#  {'_id': ObjectId('573a1394f29313caabce046d'), 'title': '12 Angry Men'},
#  {'_id': ObjectId('573a1394f29313caabce0483'),
#   'title': 'An Affair to Remember'},
#  {'_id': ObjectId('573a1394f29313caabce0484'), 'title': '3:10 to Yuma'},
#  {'_id': ObjectId('573a1394f29313caabce048d'), 'title': 'April Love'},
#  {'_id': ObjectId('573a1394f29313caabce0496'), 'title': 'Bitter Victory'},
#  {'_id': ObjectId('573a1394f29313caabce049e'),
#   'title': 'The Adventures of Arsène Lupin'},
#  {'_id': ObjectId('573a1394f29313caabce04a1'), 'title': 'The Bachelor Party'},
#  {'_id': ObjectId('573a1394f29313caabce04aa'), 'title': 'Baby Face Nelson'},
#  {'_id': ObjectId('573a1394f29313caabce04e5'),
#   'title': 'The Bridge on the River Kwai'},
#  {'_id': ObjectId('573a1394f29313caabce0511'), 'title': 'He Who Must Die'},
#  {'_id': ObjectId('573a1394f29313caabce0536'), 'title': 'Designing Woman'},
#  {'_id': ObjectId('573a1394f29313caabce0553'),
#   'title': "Don't Go Near the Water"},
#  {'_id': ObjectId('573a1394f29313caabce0565'), 'title': 'The Enemy Below'},
#  {'_id': ObjectId('573a1394f29313caabce0574'), 'title': 'A Face in the Crowd'},
#  {'_id': ObjectId('573a1394f29313caabce057c'), 'title': 'A Farewell to Arms'},
#  {'_id': ObjectId('573a1394f29313caabce0581'), 'title': 'Fear Strikes Out'},
#  {'_id': ObjectId('573a1394f29313caabce05a5'), 'title': 'Funny Face'},
#  ...]
